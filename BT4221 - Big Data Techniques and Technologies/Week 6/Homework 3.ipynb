# %% [markdown]
# ### Part A - Movie Similarities

# %%
import sys
from pyspark import SparkConf, SparkContext
from math import sqrt

# %%
def loadMovieNames():
    movieNames = {}
    with open("u.item.txt",encoding="latin-1") as f:
        for line in f:
            fields = line.split('|')
            # print(fields[1])
            movieNames[int(fields[0])] = fields[1].encode().decode()
    return movieNames

def makePairs(user_ratings):
    (movie1, rating1) = user_ratings[1][0]
    (movie2, rating2) = user_ratings[1][1]
    return ((movie1, movie2), (rating1, rating2))

def filterDuplicates( userID_ratingsTuple ):
    # print(userID_ratingsTuple)
    (movie1, rating1) = userID_ratingsTuple[1][0]
    (movie2, rating2) = userID_ratingsTuple[1][1]
    return movie1 < movie2

def computeCosineSimilarity(ratingPairs):
    numPairs = 0
    sum_xx = sum_yy = sum_xy = 0
    for ratingX, ratingY in ratingPairs:
        sum_xx += ratingX * ratingX
        sum_yy += ratingY * ratingY
        sum_xy += ratingX * ratingY
        numPairs += 1

    numerator = sum_xy
    denominator = sqrt(sum_xx) * sqrt(sum_yy)

    score = 0
    if (denominator):
        score = (numerator / (float(denominator)))

    return (score, numPairs)

# %%
conf = SparkConf().setMaster("local[*]").setAppName("MovieSimilarities")
sc = SparkContext(conf = conf)

print("\nLoading movie names...")
nameDict = loadMovieNames()

data = sc.textFile("u.data.txt")
# Out:
# Loading movie names...

# %%
ratings = data.map(lambda l: l.split()).map(lambda l: (int(l[0]), (int(l[1]), float(l[2]))))

print("\n\n ratings rdd: ")
print(ratings.take(5))
print('\n')
# Out:
#  ratings rdd:
# [(196, (242, 3.0)), (186, (302, 3.0)), (22, (377, 1.0)), (244, (51, 2.0)), (166, (346, 1.0))]

# %%
joinedRatings = ratings.join(ratings)
uniqueJoinedRatings = joinedRatings.filter(filterDuplicates)

moviePairs = uniqueJoinedRatings.map(makePairs)
moviePairRatings = moviePairs.groupByKey()

moviePairSimilarities = moviePairRatings.mapValues(computeCosineSimilarity).cache()
print("\n\n",moviePairSimilarities.take(10),"\n\n")
# Out:
#  [((242, 580), (0.9443699330874624, 6)), ((242, 692), (0.9203762039948743, 18)), ((242, 428), (0.9419097988977888, 15)), ((242, 340), (0.9455404837184603, 32)), ((393, 1241), (1.0, 1)), ((393, 845), (0.9492648155831498, 74)), ((381, 393), (0.9179400502049591, 47)), ((381, 1241), (0.9995120760870788, 2)), ((381, 845), (0.9681290828266734, 30)), ((251, 655), (0.9632240686356973, 17))]

# %%
if (len(sys.argv) > 1):
    scoreThreshold = 0.97
    coOccurenceThreshold = 50
    
#     movieID = 59
    
    for movieID in range(1, 101):
        print("\n", "#####", movieID, "#####")
        
        filteredResults = moviePairSimilarities.filter(lambda pair_sim: \
            (pair_sim[0][0] == movieID or pair_sim[0][1] == movieID) \
            and pair_sim[1][0] > scoreThreshold and pair_sim[1][1] > coOccurenceThreshold)
        print()
        print("\n\n",filteredResults.take(5),"\n\n")

        results = filteredResults.map(lambda pair_sim: (pair_sim[1], pair_sim[0])).sortByKey(ascending = False).take(10)

        print("Top 10 similar movies for " + nameDict[movieID])
        for result in results:
            (sim, pair) = result
            # Display the similarity result that isn't the movie we're looking at
            similarMovieID = pair[0]
            if (similarMovieID == movieID):
                similarMovieID = pair[1]
            print(nameDict[similarMovieID] + "\tscore: " + str(sim[0]) + "\tstrength: " + str(sim[1]))
    
    sc.stop()
# Out:
#  ##### 1 #####
#
#
#
#  [((1, 169), (0.9718143066672611, 90)), ((1, 969), (0.9734154958854764, 58)), ((1, 174), (0.9740842172192801, 273)), ((1, 318), (0.9704107478975155, 192)), ((1, 210), (0.9714068977811191, 223))]
#
#
# Top 10 similar movies for Toy Story (1995)
# Hamlet (1996)	score: 0.9745438715121281	strength: 67
# Raiders of the Lost Ark (1981)	score: 0.9740842172192801	strength: 273
# Cinderella (1950)	score: 0.9740029877471444	strength: 105
# Winnie the Pooh and the Blustery Day (1968)	score: 0.9734154958854764	strength: 58
# Cool Hand Luke (1967)	score: 0.9733423477201257	strength: 98
# Great Escape, The (1963)	score: 0.9732705816130491	strength: 77
# African Queen, The (1951)	score: 0.9731512715078089	strength: 101
# Apollo 13 (1995)	score: 0.9723951205383821	strength: 207
# 12 Angry Men (1957)	score: 0.9719872951015222	strength: 81
# Wrong Trousers, The (1993)	score: 0.9718143066672611	strength: 90
#
#  ##### 2 #####
#
#
#
#  []
#
#
# Top 10 similar movies for GoldenEye (1995)
#
#  ##### 3 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Four Rooms (1995)
#
#  ##### 4 #####
#
#
#
#  [((4, 302), (0.9713176091250733, 85))]
#
#
# Top 10 similar movies for Get Shorty (1995)
# L.A. Confidential (1997)	score: 0.9713176091250733	strength: 85
#
#  ##### 5 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Copycat (1995)
#
#  ##### 6 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)
#
#  ##### 7 #####
#
#
#
#  [((7, 163), (0.9707027476543477, 55)), ((7, 272), (0.9727237367288236, 77)), ((7, 169), (0.9727564181124363, 81)), ((7, 425), (0.9775560680365825, 60)), ((7, 657), (0.9728924892595927, 83))]
#
#
# Top 10 similar movies for Twelve Monkeys (1995)
# Bob Roberts (1992)	score: 0.9775560680365825	strength: 60
# Manchurian Candidate, The (1962)	score: 0.9728924892595927	strength: 83
# Wrong Trousers, The (1993)	score: 0.9727564181124363	strength: 81
# Good Will Hunting (1997)	score: 0.9727237367288236	strength: 77
# Return of the Pink Panther, The (1974)	score: 0.9707027476543477	strength: 55
#
#  ##### 8 #####
#
#
#
#  [((8, 657), (0.9707481140710963, 66)), ((8, 484), (0.9717924592249771, 62)), ((8, 480), (0.9727185836891374, 82)), ((8, 684), (0.9716013212709038, 84)), ((8, 427), (0.9724024830984216, 101))]
#
#
# Top 10 similar movies for Babe (1995)
# Vertigo (1958)	score: 0.9760932292330491	strength: 92
# North by Northwest (1959)	score: 0.9727185836891374	strength: 82
# To Kill a Mockingbird (1962)	score: 0.9724024830984216	strength: 101
# Maltese Falcon, The (1941)	score: 0.9717924592249771	strength: 62
# In the Line of Fire (1993)	score: 0.9716013212709038	strength: 84
# Manchurian Candidate, The (1962)	score: 0.9707481140710963	strength: 66
# Glory (1989)	score: 0.9702703226524435	strength: 86
#
#  ##### 9 #####
#
#
#
#  [((9, 357), (0.9725880616432352, 122)), ((9, 169), (0.9725451121957068, 51)), ((9, 317), (0.9722812127550535, 66)), ((9, 285), (0.970464361675724, 97)), ((9, 58), (0.9712873538535518, 104))]
#
#
# Top 10 similar movies for Dead Man Walking (1995)
# Nikita (La Femme Nikita) (1990)	score: 0.9770878135625772	strength: 60
# Lawrence of Arabia (1962)	score: 0.9750833050674294	strength: 77
# Cinema Paradiso (1988)	score: 0.9748749095268772	strength: 58
# Citizen Kane (1941)	score: 0.9743509227200203	strength: 92
# One Flew Over the Cuckoo's Nest (1975)	score: 0.9725880616432352	strength: 122
# Wrong Trousers, The (1993)	score: 0.9725451121957068	strength: 51
# Some Like It Hot (1959)	score: 0.9724667216258241	strength: 60
# In the Name of the Father (1993)	score: 0.9722812127550535	strength: 66
# Amadeus (1984)	score: 0.9722639856522068	strength: 125
# Quiz Show (1994)	score: 0.9712873538535518	strength: 104
#
#  ##### 10 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Richard III (1995)
#
#  ##### 11 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Seven (Se7en) (1995)
#
#  ##### 12 #####
#
#
#
#  [((12, 174), (0.9725193812371697, 216)), ((12, 98), (0.9734456000089852, 212)), ((12, 210), (0.9744749043834054, 175)), ((12, 50), (0.9724956031333988, 223)), ((12, 302), (0.9816869323101214, 113))]
#
#
# Top 10 similar movies for Usual Suspects, The (1995)
# Close Shave, A (1995)	score: 0.9819256006071412	strength: 56
# L.A. Confidential (1997)	score: 0.9816869323101214	strength: 113
# Sling Blade (1996)	score: 0.980468570034675	strength: 94
# Rear Window (1954)	score: 0.980441832864182	strength: 115
# Shawshank Redemption, The (1994)	score: 0.9792067644351858	strength: 177
# Manchurian Candidate, The (1962)	score: 0.9789963985081663	strength: 75
# Wrong Trousers, The (1993)	score: 0.9787901543866219	strength: 68
# Good Will Hunting (1997)	score: 0.9781245483949754	strength: 65
# Apt Pupil (1998)	score: 0.9762169825124449	strength: 54
# Godfather, The (1972)	score: 0.9754550490486855	strength: 176
#
#  ##### 13 #####
#
#
#
#  [((13, 170), (0.9713129021039416, 53)), ((13, 479), (0.9738893501142089, 66))]
#
#
# Top 10 similar movies for Mighty Aphrodite (1995)
# Vertigo (1958)	score: 0.9738893501142089	strength: 66
# Cinema Paradiso (1988)	score: 0.9713129021039416	strength: 53
#
#  ##### 14 #####
#
#
#
#  [((14, 480), (0.9719390578731835, 55)), ((14, 427), (0.9713794766350303, 58)), ((14, 479), (0.9752335446133259, 58)), ((14, 483), (0.970254667086997, 72)), ((14, 527), (0.9759939694658367, 58))]
#
#
# Top 10 similar movies for Postino, Il (1994)
# Cinema Paradiso (1988)	score: 0.979454098487592	strength: 70
# Gandhi (1982)	score: 0.9759939694658367	strength: 58
# Vertigo (1958)	score: 0.9752335446133259	strength: 58
# Quiz Show (1994)	score: 0.9724884182023371	strength: 56
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)	score: 0.9720206888863536	strength: 58
# North by Northwest (1959)	score: 0.9719390578731835	strength: 55
# To Kill a Mockingbird (1962)	score: 0.9713794766350303	strength: 58
# One Flew Over the Cuckoo's Nest (1975)	score: 0.9704905381458678	strength: 73
# Casablanca (1942)	score: 0.970254667086997	strength: 72
# My Left Foot (1989)	score: 0.9702106316263525	strength: 57
#
#  ##### 15 #####
#
#
#
#  [((15, 64), (0.9704861108640814, 126)), ((15, 732), (0.9707599187251634, 90)), ((15, 272), (0.9705162058373576, 53)), ((15, 318), (0.9716656912374539, 129))]
#
#
# Top 10 similar movies for Mr. Holland's Opus (1995)
# Schindler's List (1993)	score: 0.9716656912374539	strength: 129
# Dave (1993)	score: 0.9707599187251634	strength: 90
# Good Will Hunting (1997)	score: 0.9705162058373576	strength: 53
# Shawshank Redemption, The (1994)	score: 0.9704861108640814	strength: 126
#
#  ##### 16 #####
#
#
#
#  []
#
#
# Top 10 similar movies for French Twist (Gazon maudit) (1995)
#
#  ##### 17 #####
#
#
#
#  []
#
#
# Top 10 similar movies for From Dusk Till Dawn (1996)
#
#  ##### 18 #####
#
#
#
#  []
#
#
# Top 10 similar movies for White Balloon, The (1995)
#
#  ##### 19 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Antonia's Line (1995)
#
#  ##### 20 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Angels and Insects (1995)
#
#  ##### 21 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Muppet Treasure Island (1996)
#
#  ##### 22 #####
#
#
#
#  [((22, 232), (0.9732635832330633, 84)), ((22, 64), (0.9747384571685911, 192)), ((22, 28), (0.9751504260280339, 181)), ((22, 404), (0.9705738416344881, 66)), ((22, 684), (0.9734368972698565, 115))]
#
#
# Top 10 similar movies for Braveheart (1995)
# Titanic (1997)	score: 0.9773906047511945	strength: 114
# Raiders of the Lost Ark (1981)	score: 0.9761061434973067	strength: 258
# Apollo 13 (1995)	score: 0.9751504260280339	strength: 181
# Glory (1989)	score: 0.9747435644565872	strength: 127
# Shawshank Redemption, The (1994)	score: 0.9747384571685911	strength: 192
# Fugitive, The (1993)	score: 0.9742197543830059	strength: 212
# In the Line of Fire (1993)	score: 0.9734368972698565	strength: 115
# Young Guns (1988)	score: 0.9732635832330633	strength: 84
# Good Will Hunting (1997)	score: 0.9718462637907347	strength: 65
# Schindler's List (1993)	score: 0.9716654666263744	strength: 192
#
#  ##### 23 #####
#
#
#
#  [((23, 427), (0.9761918020570957, 100)), ((23, 187), (0.9774943583413607, 115)), ((23, 511), (0.971437365800779, 81)), ((23, 483), (0.9741930941680151, 113)), ((23, 127), (0.9776190878574484, 142))]
#
#
# Top 10 similar movies for Taxi Driver (1976)
# L.A. Confidential (1997)	score: 0.9831391415239706	strength: 67
# 12 Angry Men (1957)	score: 0.9807282468007394	strength: 65
# Psycho (1960)	score: 0.9803832898030147	strength: 117
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)	score: 0.9791045211011964	strength: 102
# Chinatown (1974)	score: 0.9784048778746769	strength: 93
# Godfather, The (1972)	score: 0.9776190878574484	strength: 142
# Godfather: Part II, The (1974)	score: 0.9774943583413607	strength: 115
# Rear Window (1954)	score: 0.9773554539154067	strength: 104
# Glory (1989)	score: 0.9773023565475534	strength: 74
# North by Northwest (1959)	score: 0.9772972361416615	strength: 91
#
#  ##### 24 #####
#  []
#
#
# Top 10 similar movies for Rumble in the Bronx (1995)
#
#  ##### 25 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Birdcage, The (1996)
#
#  ##### 26 #####
#
#
#
#  [((26, 70), (0.9724123902987725, 55))]
#
#
# Top 10 similar movies for Brothers McMullen, The (1995)
# Four Weddings and a Funeral (1994)	score: 0.9724123902987725	strength: 55
#
#  ##### 27 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Bad Boys (1995)
#
#  ##### 28 #####
#
#
#
#  [((22, 28), (0.9751504260280339, 181)), ((28, 66), (0.9718399443607805, 99)), ((28, 174), (0.9752200969495095, 242)), ((28, 318), (0.972153895693656, 181)), ((28, 50), (0.9708054799005053, 243))]
#
#
# Top 10 similar movies for Apollo 13 (1995)
# Hamlet (1996)	score: 0.9773582189340098	strength: 57
# Shawshank Redemption, The (1994)	score: 0.9772412307116896	strength: 175
# Raiders of the Lost Ark (1981)	score: 0.9752200969495095	strength: 242
# Braveheart (1995)	score: 0.9751504260280339	strength: 181
# Great Escape, The (1963)	score: 0.974864223139754	strength: 77
# Hunt for Red October, The (1990)	score: 0.9738599593846253	strength: 145
# Right Stuff, The (1983)	score: 0.9736544021416819	strength: 113
# Winnie the Pooh and the Blustery Day (1968)	score: 0.97359225355417	strength: 52
# Sling Blade (1996)	score: 0.9735666311742603	strength: 86
# Gandhi (1982)	score: 0.9733695330868046	strength: 126
#
#  ##### 29 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Batman Forever (1995)
#
#  ##### 30 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Belle de jour (1967)
#
#  ##### 31 #####
#
#
#
#  [((31, 483), (0.9708909787523984, 76)), ((31, 87), (0.9711921199964219, 62)), ((31, 199), (0.9704987380703006, 59)), ((31, 79), (0.9756851553120212, 125)), ((31, 523), (0.9741334960123446, 52))]
#
#
# Top 10 similar movies for Crimson Tide (1995)
# In the Line of Fire (1993)	score: 0.97986926246734	strength: 83
# Hunt for Red October, The (1990)	score: 0.9781305861335734	strength: 103
# Outbreak (1995)	score: 0.9763235761786628	strength: 68
# Fugitive, The (1993)	score: 0.9756851553120212	strength: 125
# True Lies (1994)	score: 0.9742377628962092	strength: 101
# Cool Hand Luke (1967)	score: 0.9741334960123446	strength: 52
# River Wild, The (1994)	score: 0.9728960801779989	strength: 52
# Terminator 2: Judgment Day (1991)	score: 0.9728646541142886	strength: 120
# Con Air (1997)	score: 0.9728173053206879	strength: 51
# Silence of the Lambs, The (1991)	score: 0.9720606560066626	strength: 133
#
#  ##### 32 #####
#
#
#
#  [((32, 182), (0.9740379531181461, 57)), ((32, 474), (0.9708284216957398, 52)), ((32, 603), (0.9722724326782708, 52))]
#
#
# Top 10 similar movies for Crumb (1994)
# GoodFellas (1990)	score: 0.9740379531181461	strength: 57
# Rear Window (1954)	score: 0.9722724326782708	strength: 52
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)	score: 0.9708284216957398	strength: 52
#
#  ##### 33 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Desperado (1995)
#
#  ##### 34 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Doom Generation, The (1995)
#
#  ##### 35 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Free Willy 2: The Adventure Home (1995)
#
#  ##### 36 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Mad Love (1995)
#
#  ##### 37 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Nadja (1994)
#
#  ##### 38 #####
#
#
#
#  [((38, 66), (0.9708289851315188, 67))]
#
#
# Top 10 similar movies for Net, The (1995)
# While You Were Sleeping (1995)	score: 0.9708289851315188	strength: 67
#
#  ##### 39 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Strange Days (1995)
#
#  ##### 40 #####
#
#
#
#  []
#
#
# Top 10 similar movies for To Wong Foo, Thanks for Everything! Julie Newmar (1995)
#
#  ##### 41 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Billy Madison (1995)
#
#  ##### 42 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Clerks (1994)
#
#  ##### 43 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Disclosure (1994)
#
#  ##### 44 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Dolores Claiborne (1994)
#
#  ##### 45 #####
#
#
#
#  [((45, 100), (0.9779734871069076, 66))]
#
#
# Top 10 similar movies for Eat Drink Man Woman (1994)
# Fargo (1996)	score: 0.9779734871069076	strength: 66
#
#  ##### 46 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Exotica (1994)
#
#  ##### 47 #####
#
#
#
#  [((47, 223), (0.9717259251977122, 52))]
#
#
# Top 10 similar movies for Ed Wood (1994)
# Sling Blade (1996)	score: 0.9717259251977122	strength: 52
#
#  ##### 48 #####
#
#
#
#  [((48, 178), (0.9707380076445082, 52)), ((48, 134), (0.9746181596812626, 60)), ((48, 182), (0.9741176953751591, 67)), ((48, 185), (0.97123783812028, 56)), ((48, 64), (0.9732772777131453, 91))]
#
#
# Top 10 similar movies for Hoop Dreams (1994)
# Lawrence of Arabia (1962)	score: 0.9750545565425166	strength: 52
# Citizen Kane (1941)	score: 0.9746181596812626	strength: 60
# GoodFellas (1990)	score: 0.9741176953751591	strength: 67
# Shawshank Redemption, The (1994)	score: 0.9732772777131453	strength: 91
# To Kill a Mockingbird (1962)	score: 0.9713232168030701	strength: 64
# Psycho (1960)	score: 0.97123783812028	strength: 56
# Casablanca (1942)	score: 0.9710330351868689	strength: 68
# 12 Angry Men (1957)	score: 0.9707380076445082	strength: 52
# Dead Man Walking (1995)	score: 0.9705315453942256	strength: 63
# Fargo (1996)	score: 0.9700110993420206	strength: 91
#
#  ##### 49 #####
#
#
#
#  []
#
#
# Top 10 similar movies for I.Q. (1994)
#
#  ##### 50 #####
#
#
#
#  [((50, 172), (0.9895522078385338, 345)), ((28, 50), (0.9708054799005053, 243)), ((12, 50), (0.9724956031333988, 223)), ((50, 408), (0.9775948291054827, 92)), ((50, 404), (0.971249981890631, 95))]
#
#
# Top 10 similar movies for Star Wars (1977)
# Empire Strikes Back, The (1980)	score: 0.9895522078385338	strength: 345
# Return of the Jedi (1983)	score: 0.9857230861253026	strength: 480
# Raiders of the Lost Ark (1981)	score: 0.981760098872619	strength: 380
# 20,000 Leagues Under the Sea (1954)	score: 0.9789385605497993	strength: 68
# 12 Angry Men (1957)	score: 0.9776576120448436	strength: 109
# Close Shave, A (1995)	score: 0.9775948291054827	strength: 92
# African Queen, The (1951)	score: 0.9764692222674887	strength: 138
# Sting, The (1973)	score: 0.9751512937740359	strength: 204
# Wrong Trousers, The (1993)	score: 0.9748681355460885	strength: 103
# Wallace & Gromit: The Best of Aardman Animation (1996)	score: 0.9741816128302572	strength: 58
#
#  ##### 51 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Legends of the Fall (1994)
#
#  ##### 52 #####
#
#
#
#  [((52, 86), (0.9813832610614274, 57)), ((52, 134), (0.9718000366653027, 52)), ((52, 170), (0.972075937160459, 52)), ((52, 191), (0.9722116264110299, 74)), ((52, 435), (0.9702584474644415, 54))]
#
#
# Top 10 similar movies for Madness of King George, The (1994)
# Remains of the Day, The (1993)	score: 0.9813832610614274	strength: 57
# Sense and Sensibility (1995)	score: 0.975418270032756	strength: 54
# Amadeus (1984)	score: 0.9722116264110299	strength: 74
# Cinema Paradiso (1988)	score: 0.972075937160459	strength: 52
# Citizen Kane (1941)	score: 0.9718000366653027	strength: 52
# Butch Cassidy and the Sundance Kid (1969)	score: 0.9702584474644415	strength: 54
#
#  ##### 53 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Natural Born Killers (1994)
#
#  ##### 54 #####
#
#
#
#  [((54, 684), (0.97151311902361, 61)), ((54, 282), (0.9761999126966577, 57)), ((54, 742), (0.9722655042354755, 67)), ((31, 54), (0.9763235761786628, 68))]
#
#
# Top 10 similar movies for Outbreak (1995)
# Crimson Tide (1995)	score: 0.9763235761786628	strength: 68
# Time to Kill, A (1996)	score: 0.9761999126966577	strength: 57
# Ransom (1996)	score: 0.9722655042354755	strength: 67
# In the Line of Fire (1993)	score: 0.97151311902361	strength: 61
#
#  ##### 55 #####
#
#
#
#  [((55, 483), (0.9746109312980196, 63)), ((55, 198), (0.9766815708787464, 59))]
#
#
# Top 10 similar movies for Professional, The (1994)
# Nikita (La Femme Nikita) (1990)	score: 0.9766815708787464	strength: 59
# Casablanca (1942)	score: 0.9746109312980196	strength: 63
#
#  ##### 56 #####
#
#
#
#  [((56, 346), (0.9706179145690377, 55)), ((56, 461), (0.9743848338030823, 68)), ((56, 293), (0.9738247291149608, 75)), ((56, 92), (0.9707295689679896, 99)), ((56, 156), (0.9740674165782123, 134))]
#
#
# Top 10 similar movies for Pulp Fiction (1994)
# Smoke (1995)	score: 0.9743848338030823	strength: 68
# Reservoir Dogs (1992)	score: 0.9740674165782123	strength: 134
# Donnie Brasco (1997)	score: 0.9738247291149608	strength: 75
# Sling Blade (1996)	score: 0.9713796344244161	strength: 111
# True Romance (1993)	score: 0.9707295689679896	strength: 99
# Jackie Brown (1997)	score: 0.9706179145690377	strength: 55
# Carlito's Way (1993)	score: 0.9706021261759088	strength: 52
#
#  ##### 57 #####
#  []
#
#
# Top 10 similar movies for Priest (1994)
#
#  ##### 58 #####
#
#
#
#  [((58, 92), (0.9732060770757048, 54)), ((58, 124), (0.9703668096834813, 62)), ((58, 484), (0.9778080588219972, 55)), ((58, 480), (0.9731637048883437, 77)), ((9, 58), (0.9712873538535518, 104))]
#
#
# Top 10 similar movies for Quiz Show (1994)
# Manchurian Candidate, The (1962)	score: 0.9842058102544757	strength: 59
# Wrong Trousers, The (1993)	score: 0.9798872350798274	strength: 52
# Maltese Falcon, The (1941)	score: 0.9778080588219972	strength: 55
# Butch Cassidy and the Sundance Kid (1969)	score: 0.973460591401908	strength: 88
# Casablanca (1942)	score: 0.9733997456758868	strength: 104
# Rear Window (1954)	score: 0.973294969543555	strength: 83
# True Romance (1993)	score: 0.9732060770757048	strength: 54
# North by Northwest (1959)	score: 0.9731637048883437	strength: 77
# Platoon (1986)	score: 0.9728125517288128	strength: 65
# Four Weddings and a Funeral (1994)	score: 0.972577924214564	strength: 109
#
#  ##### 59 #####
#
#
#
#  [((59, 179), (0.9707586804195458, 54)), ((59, 60), (0.9869656221961467, 55)), ((59, 168), (0.9747312057131576, 52)), ((59, 89), (0.9720803147887267, 52)), ((59, 197), (0.9712705539502677, 54))]
#
#
# Top 10 similar movies for Three Colors: Red (1994)
# Three Colors: White (1994)	score: 0.9872137267597849	strength: 52
# Three Colors: Blue (1993)	score: 0.9869656221961467	strength: 55
# Monty Python and the Holy Grail (1974)	score: 0.9747312057131576	strength: 52
# Blade Runner (1982)	score: 0.9720803147887267	strength: 52
# Graduate, The (1967)	score: 0.9712705539502677	strength: 54
# Clockwork Orange, A (1971)	score: 0.9707586804195458	strength: 54
#
#  ##### 60 #####
#
#
#
#  [((59, 60), (0.9869656221961467, 55))]
#
#
# Top 10 similar movies for Three Colors: Blue (1993)
# Three Colors: Red (1994)	score: 0.9869656221961467	strength: 55
#
#  ##### 61 #####
#
#
#
#  [((59, 61), (0.9872137267597849, 52))]
#
#
# Top 10 similar movies for Three Colors: White (1994)
# Three Colors: Red (1994)	score: 0.9872137267597849	strength: 52
#
#  ##### 62 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Stargate (1994)
#
#  ##### 63 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Santa Clause, The (1994)
#
#  ##### 64 #####
#
#
#
#  [((22, 64), (0.9747384571685911, 192)), ((64, 186), (0.9714569867725117, 156)), ((64, 174), (0.9730371019033975, 237)), ((64, 318), (0.9812230741934839, 193)), ((64, 170), (0.973548300435211, 77))]
#
#
# Top 10 similar movies for Shawshank Redemption, The (1994)
# Glory (1989)	score: 0.9839966726106273	strength: 123
# Silence of the Lambs, The (1991)	score: 0.9820460664993174	strength: 215
# Schindler's List (1993)	score: 0.9812230741934839	strength: 193
# Good Will Hunting (1997)	score: 0.9795537178177353	strength: 69
# One Flew Over the Cuckoo's Nest (1975)	score: 0.9793664193680992	strength: 173
# Usual Suspects, The (1995)	score: 0.9792067644351858	strength: 177
# Sling Blade (1996)	score: 0.9787360267625244	strength: 91
# To Kill a Mockingbird (1962)	score: 0.9785024275416393	strength: 133
# Stand by Me (1986)	score: 0.9780953971163547	strength: 148
# Fugitive, The (1993)	score: 0.9779481552473841	strength: 192
#
#  ##### 65 #####
#
#
#
#  []
#
#
# Top 10 similar movies for What's Eating Gilbert Grape (1993)
#
#  ##### 66 #####
#
#
#
#  [((66, 732), (0.971045121586345, 97)), ((28, 66), (0.9718399443607805, 99)), ((38, 66), (0.9708289851315188, 67))]
#
#
# Top 10 similar movies for While You Were Sleeping (1995)
# Apollo 13 (1995)	score: 0.9718399443607805	strength: 99
# Dave (1993)	score: 0.971045121586345	strength: 97
# Net, The (1995)	score: 0.9708289851315188	strength: 67
#
#  ##### 67 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Ace Ventura: Pet Detective (1994)
#
#  ##### 68 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Crow, The (1994)
#
#  ##### 69 #####
#
#
#
#  [((69, 404), (0.9711061254958537, 82))]
#
#
# Top 10 similar movies for Forrest Gump (1994)
# Pinocchio (1940)	score: 0.9711061254958537	strength: 82
#
#  ##### 70 #####
#
#
#
#  [((70, 272), (0.9714251338886775, 63)), ((70, 483), (0.97166319272357, 117)), ((70, 479), (0.972462007568743, 93)), ((26, 70), (0.9724123902987725, 55)), ((58, 70), (0.972577924214564, 109))]
#
#
# Top 10 similar movies for Four Weddings and a Funeral (1994)
# Quiz Show (1994)	score: 0.972577924214564	strength: 109
# Vertigo (1958)	score: 0.972462007568743	strength: 93
# Brothers McMullen, The (1995)	score: 0.9724123902987725	strength: 55
# Cinema Paradiso (1988)	score: 0.9720353884119554	strength: 82
# Casablanca (1942)	score: 0.97166319272357	strength: 117
# Good Will Hunting (1997)	score: 0.9714251338886775	strength: 63
# Philadelphia Story, The (1940)	score: 0.9702199007431	strength: 54
#
#  ##### 71 #####
#
#
#
#  [((71, 95), (0.9729017053707703, 167)), ((71, 496), (0.9707942254118238, 128)), ((71, 520), (0.9731943155031116, 63)), ((1, 71), (0.9711875801700128, 173)), ((71, 657), (0.9791417549036365, 51))]
#
#
# Top 10 similar movies for Lion King, The (1994)
# Manchurian Candidate, The (1962)	score: 0.9791417549036365	strength: 51
# Great Escape, The (1963)	score: 0.9731943155031116	strength: 63
# Aladdin (1992)	score: 0.9729017053707703	strength: 167
# Winnie the Pooh and the Blustery Day (1968)	score: 0.9722198659285328	strength: 53
# Toy Story (1995)	score: 0.9711875801700128	strength: 173
# It's a Wonderful Life (1946)	score: 0.9707942254118238	strength: 128
# African Queen, The (1951)	score: 0.9707738128601994	strength: 80
#
#  ##### 72 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Mask, The (1994)
#
#  ##### 73 #####
#
#
#
#  [((73, 210), (0.9718461203321167, 110))]
#
#
# Top 10 similar movies for Maverick (1994)
# Indiana Jones and the Last Crusade (1989)	score: 0.9718461203321167	strength: 110
#
#  ##### 74 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Faster Pussycat! Kill! Kill! (1965)
#
#  ##### 75 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Brother Minister: The Assassination of Malcolm X (1994)
#
#  ##### 76 #####
#
#
#
#  [((56, 76), (0.9706021261759088, 52))]
#
#
# Top 10 similar movies for Carlito's Way (1993)
# Pulp Fiction (1994)	score: 0.9706021261759088	strength: 52
#
#  ##### 77 #####
#
#
#
#  [((77, 265), (0.9717900139818982, 95)), ((77, 385), (0.9722335965085784, 101)), ((77, 174), (0.9702342433661469, 128)), ((31, 77), (0.9719804748194554, 84)), ((77, 79), (0.972924880160013, 121))]
#
#
# Top 10 similar movies for Firm, The (1993)
# Fugitive, The (1993)	score: 0.972924880160013	strength: 121
# True Lies (1994)	score: 0.9722335965085784	strength: 101
# Crimson Tide (1995)	score: 0.9719804748194554	strength: 84
# Hunt for Red October, The (1990)	score: 0.9717900139818982	strength: 95
# Raiders of the Lost Ark (1981)	score: 0.9702342433661469	strength: 128
#
#  ##### 78 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Free Willy (1993)
#
#  ##### 79 #####
#
#
#
#  [((79, 291), (0.9703841312471755, 74)), ((79, 191), (0.9722250395523453, 170)), ((79, 483), (0.9737987003879902, 163)), ((79, 523), (0.9701447887872959, 106)), ((79, 427), (0.9780205049728652, 146))]
#
#
# Top 10 similar movies for Fugitive, The (1993)
# In the Line of Fire (1993)	score: 0.979072216824887	strength: 147
# Glory (1989)	score: 0.9781198268889071	strength: 132
# Schindler's List (1993)	score: 0.9780583756223169	strength: 195
# To Kill a Mockingbird (1962)	score: 0.9780205049728652	strength: 146
# Shawshank Redemption, The (1994)	score: 0.9779481552473841	strength: 192
# Raiders of the Lost Ark (1981)	score: 0.9770829376335967	strength: 286
# Hunt for Red October, The (1990)	score: 0.9767280786043834	strength: 180
# Crimson Tide (1995)	score: 0.9756851553120212	strength: 125
# One Flew Over the Cuckoo's Nest (1975)	score: 0.9754224016326563	strength: 168
# Back to the Future (1985)	score: 0.9751564138957003	strength: 239
#
#  ##### 80 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Hot Shots! Part Deux (1993)
#
#  ##### 81 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Hudsucker Proxy, The (1994)
#
#  ##### 82 #####
#
#
#
#  [((79, 82), (0.9717703765630371, 200))]
#
#
# Top 10 similar movies for Jurassic Park (1993)
# Fugitive, The (1993)	score: 0.9717703765630371	strength: 200
#
#  ##### 83 #####
#
#
#
#  [((83, 515), (0.9722262960300503, 59)), ((83, 223), (0.9756579379242957, 54)), ((83, 483), (0.9745198631104962, 99)), ((83, 471), (0.9704438576346874, 58)), ((83, 275), (0.9734200179279634, 96))]
#
#
# Top 10 similar movies for Much Ado About Nothing (1993)
# Henry V (1989)	score: 0.9786140386564366	strength: 82
# Sling Blade (1996)	score: 0.9756579379242957	strength: 54
# Grosse Pointe Blank (1997)	score: 0.974991399749518	strength: 52
# Casablanca (1942)	score: 0.9745198631104962	strength: 99
# Room with a View, A (1986)	score: 0.9734570191110895	strength: 71
# Sense and Sensibility (1995)	score: 0.9734200179279634	strength: 96
# African Queen, The (1951)	score: 0.9729331050329326	strength: 64
# Boot, Das (1981)	score: 0.9722262960300503	strength: 59
# Schindler's List (1993)	score: 0.9713844524683196	strength: 102
# Strictly Ballroom (1992)	score: 0.9709319071347243	strength: 58
#
#  ##### 84 #####
#  []
#
#
# Top 10 similar movies for Robert A. Heinlein's The Puppet Masters (1994)
#
#  ##### 85 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Ref, The (1994)
#
#  ##### 86 #####
#
#
#
#  [((52, 86), (0.9813832610614274, 57)), ((86, 528), (0.9710697306083039, 55)), ((86, 275), (0.971477179832882, 89)), ((86, 170), (0.9734104054073575, 64)), ((86, 285), (0.970887027453041, 54))]
#
#
# Top 10 similar movies for Remains of the Day, The (1993)
# Madness of King George, The (1994)	score: 0.9813832610614274	strength: 57
# Cinema Paradiso (1988)	score: 0.9734104054073575	strength: 64
# Sense and Sensibility (1995)	score: 0.971477179832882	strength: 89
# Killing Fields, The (1984)	score: 0.9710697306083039	strength: 55
# Secrets & Lies (1996)	score: 0.970887027453041	strength: 54
#
#  ##### 87 #####
#
#
#
#  [((87, 523), (0.9794493559722057, 58)), ((87, 603), (0.9721033262838495, 62)), ((87, 479), (0.97123616207553, 58)), ((31, 87), (0.9711921199964219, 62)), ((87, 124), (0.9701509628367333, 54))]
#
#
# Top 10 similar movies for Searching for Bobby Fischer (1993)
# Cool Hand Luke (1967)	score: 0.9794493559722057	strength: 58
# In the Line of Fire (1993)	score: 0.9748267180442588	strength: 65
# Shawshank Redemption, The (1994)	score: 0.9742703934010231	strength: 100
# Sting, The (1973)	score: 0.9729942706205965	strength: 90
# It's a Wonderful Life (1946)	score: 0.9721342310668405	strength: 72
# Rear Window (1954)	score: 0.9721033262838495	strength: 62
# Quiz Show (1994)	score: 0.9718159624065494	strength: 76
# Hunt for Red October, The (1990)	score: 0.9715284694938956	strength: 78
# Vertigo (1958)	score: 0.97123616207553	strength: 58
# Crimson Tide (1995)	score: 0.9711921199964219	strength: 62
#
#  ##### 88 #####
#
#
#
#  [((88, 651), (0.9702336398368621, 85))]
#
#
# Top 10 similar movies for Sleepless in Seattle (1993)
# Glory (1989)	score: 0.9702336398368621	strength: 85
#
#  ##### 89 #####
#
#
#
#  [((89, 169), (0.9802355605129937, 78)), ((89, 293), (0.9711426758496481, 55)), ((89, 178), (0.9719726601741141, 73)), ((89, 498), (0.9707618142423553, 100)), ((89, 434), (0.9705769997140351, 60))]
#
#
# Top 10 similar movies for Blade Runner (1982)
# Close Shave, A (1995)	score: 0.9826677496368988	strength: 58
# Wrong Trousers, The (1993)	score: 0.9802355605129937	strength: 78
# Good Will Hunting (1997)	score: 0.975429628548115	strength: 63
# Vertigo (1958)	score: 0.9734938009261395	strength: 110
# Three Colors: Red (1994)	score: 0.9720803147887267	strength: 52
# Treasure of the Sierra Madre, The (1948)	score: 0.9720473523399971	strength: 51
# 12 Angry Men (1957)	score: 0.9719726601741141	strength: 73
# Alien (1979)	score: 0.9719001598775506	strength: 201
# Casablanca (1942)	score: 0.9713708712931806	strength: 149
# Maltese Falcon, The (1941)	score: 0.9713005134681663	strength: 87
#
#  ##### 90 #####
#
#
#
#  []
#
#
# Top 10 similar movies for So I Married an Axe Murderer (1993)
#
#  ##### 91 #####
#
#
#
#  [((91, 169), (0.971667675646064, 51))]
#
#
# Top 10 similar movies for Nightmare Before Christmas, The (1993)
# Wrong Trousers, The (1993)	score: 0.971667675646064	strength: 51
#
#  ##### 92 #####
#
#
#
#  [((58, 92), (0.9732060770757048, 54)), ((92, 182), (0.9714876212755238, 82)), ((92, 200), (0.9733546184533022, 59)), ((92, 156), (0.9821765785187014, 59)), ((56, 92), (0.9707295689679896, 99))]
#
#
# Top 10 similar movies for True Romance (1993)
# Reservoir Dogs (1992)	score: 0.9821765785187014	strength: 59
# Shining, The (1980)	score: 0.9733546184533022	strength: 59
# Quiz Show (1994)	score: 0.9732060770757048	strength: 54
# Trainspotting (1996)	score: 0.9726438417749624	strength: 54
# GoodFellas (1990)	score: 0.9714876212755238	strength: 82
# Pulp Fiction (1994)	score: 0.9707295689679896	strength: 99
#
#  ##### 93 #####
#
#
#
#  [((93, 185), (0.9731063850915271, 51))]
#
#
# Top 10 similar movies for Welcome to the Dollhouse (1995)
# Psycho (1960)	score: 0.9731063850915271	strength: 51
#
#  ##### 94 #####
#
#
#
#  []
#
#
# Top 10 similar movies for Home Alone (1990)
#
#  ##### 95 #####
#
#
#
#  [((71, 95), (0.9729017053707703, 167)), ((95, 204), (0.9717033978669, 186)), ((95, 969), (0.9715647057012244, 51)), ((64, 95), (0.9731844087973376, 123)), ((95, 418), (0.971816893854722, 98))]
#
#
# Top 10 similar movies for Aladdin (1992)
# Shawshank Redemption, The (1994)	score: 0.9731844087973376	strength: 123
# Lion King, The (1994)	score: 0.9729017053707703	strength: 167
# Cinderella (1950)	score: 0.971816893854722	strength: 98
# Back to the Future (1985)	score: 0.9717033978669	strength: 186
# Winnie the Pooh and the Blustery Day (1968)	score: 0.9715647057012244	strength: 51
#
#  ##### 96 #####
#
#
#
#  [((96, 174), (0.9728933921071928, 261)), ((31, 96), (0.9728646541142886, 120)), ((96, 568), (0.9703119578684536, 182)), ((96, 204), (0.972565382011569, 219)), ((96, 408), (0.9749142227467049, 56))]
#
#
# Top 10 similar movies for Terminator 2: Judgment Day (1991)
# Terminator, The (1984)	score: 0.9780594831789371	strength: 239
# Close Shave, A (1995)	score: 0.9749142227467049	strength: 56
# Good Will Hunting (1997)	score: 0.973153710764373	strength: 62
# Raiders of the Lost Ark (1981)	score: 0.9728933921071928	strength: 261
# Crimson Tide (1995)	score: 0.9728646541142886	strength: 120
# Back to the Future (1985)	score: 0.972565382011569	strength: 219
# Courage Under Fire (1996)	score: 0.9719795195761328	strength: 106
# Speed (1994)	score: 0.9703119578684536	strength: 182
#
#  ##### 97 #####
#
#
#
#  [((97, 479), (0.9703244263932648, 96))]
#
#
# Top 10 similar movies for Dances with Wolves (1990)
# Vertigo (1958)	score: 0.9703244263932648	strength: 96
#
#  ##### 98 #####
#
#
#
#  [((98, 528), (0.971123760761402, 96)), ((98, 176), (0.9703084507176004, 240)), ((98, 484), (0.970828268169724, 109)), ((98, 408), (0.9732007491139351, 70)), ((98, 732), (0.970044467440935, 135))]
#
#
# Top 10 similar movies for Silence of the Lambs, The (1991)
# Shawshank Redemption, The (1994)	score: 0.9820460664993174	strength: 215
# Dial M for Murder (1954)	score: 0.981581215947862	strength: 58
# To Kill a Mockingbird (1962)	score: 0.9797064378902174	strength: 171
# Glory (1989)	score: 0.9795842477300154	strength: 136
# Casablanca (1942)	score: 0.9790976051286594	strength: 188
# Sling Blade (1996)	score: 0.9780578979710847	strength: 112
# 12 Angry Men (1957)	score: 0.9774123548400772	strength: 97
# Christmas Carol, A (1938)	score: 0.9769453088294542	strength: 59
# Third Man, The (1949)	score: 0.9768277198741823	strength: 51
# Rear Window (1954)	score: 0.97586974154218	strength: 160
#
#  ##### 99 #####
#
#
#
#  [((99, 483), (0.9730760124964781, 99)), ((99, 427), (0.9771995344944665, 89)), ((99, 603), (0.9703817981623712, 83)), ((99, 132), (0.9700382734344559, 123)), ((99, 404), (0.9744967741600263, 87))]
#
#
# Top 10 similar movies for Snow White and the Seven Dwarfs (1937)
# African Queen, The (1951)	score: 0.9777803595870904	strength: 70
# To Kill a Mockingbird (1962)	score: 0.9771995344944665	strength: 89
# Pinocchio (1940)	score: 0.9744967741600263	strength: 87
# Casablanca (1942)	score: 0.9730760124964781	strength: 99
# Cinderella (1950)	score: 0.9724442065693274	strength: 103
# Dumbo (1941)	score: 0.9723295953044029	strength: 95
# Singin' in the Rain (1952)	score: 0.9716878268252358	strength: 63
# North by Northwest (1959)	score: 0.9714948165972832	strength: 73
# Graduate, The (1967)	score: 0.9710765156212765	strength: 100
# Schindler's List (1993)	score: 0.9706550814533416	strength: 105
#
#  ##### 100 #####
#
#
#
#  [((100, 498), (0.9706304549561346, 114)), ((100, 302), (0.9725621288162158, 159)), ((100, 414), (0.9717705970738939, 54)), ((100, 129), (0.9700785791410053, 118)), ((100, 461), (0.9746204756063659, 67))]
#
#
# Top 10 similar movies for Fargo (1996)
# Manchurian Candidate, The (1962)	score: 0.9784391733910245	strength: 98
# Eat Drink Man Woman (1994)	score: 0.9779734871069076	strength: 66
# Rear Window (1954)	score: 0.9763016301960283	strength: 148
# Sling Blade (1996)	score: 0.9749197443320659	strength: 123
# Smoke (1995)	score: 0.9746204756063659	strength: 67
# Secrets & Lies (1996)	score: 0.9738843540602091	strength: 140
# Lone Star (1996)	score: 0.9734129022318938	strength: 171
# Third Man, The (1949)	score: 0.9732829647806052	strength: 55
# L.A. Confidential (1997)	score: 0.9725621288162158	strength: 159
# Bullets Over Broadway (1994)	score: 0.9721359115893622	strength: 72

# %% [markdown]
# ### Part B - Wikipedia

# %%
import os, re, json
os.environ['SPARK_HOME'] = 'C:\spark'

import findspark
findspark.init()

from math import log2, log10, ceil
from functools import partial
from pyspark import SparkContext

# %%
def ceil5(x):
    return ceil(x/5)*5

def get_winner_loser(match):
    ms = match.split(',')
    return (ms[20], ms[10])

def initialize_voting(losses):
    return {'losses': losses,
            'n_losses': len(losses),
            'rating': 100}

def empty_ratings(d):
    d['rating'] = 0
    return d

def allocate_points(acc, nxt, i):
    k,v = nxt
    
    if i == 0:
        boost = 100 / (v['n_losses']+.01)
    
    else:
        boost = v['rating'] / (v['n_losses'] + .01)
        
    for loss in v['losses']:
        if loss not in acc.keys():
            acc[loss] = {'losses':[], 'n_losses': 0}
        
        opp_rating = acc.get(loss,{}).get('rating',0)
        acc[loss]['rating'] = opp_rating + boost
    
    return acc

def combine_scores(a, b):
    for k,v in b.items():
        try:
            a[k]['rating'] = a[k]['rating'] + b[k]['rating']
        except KeyError:
            a[k] = v
    
    return a

# %%
try:
    sc.stop()
except:
    try:
        spark.stop()
    except:
        pass

if __name__ == "__main__":
    sc = SparkContext(appName="WikiMap")
    entries = sc.textFile("wikipedia_edges.txt")
    xs = entries.flatMap(lambda x:x.split('\n'))\
                 .map(lambda x:x.split('\t'))\
                 .groupByKey()\
                 .mapValues(initialize_voting)

    for i in range(7):
        if i > 0:
            xs = sc.parallelize(zs.items())

        acc = dict(xs.mapValues(empty_ratings).collect())
        agg_f = partial(allocate_points, i=i)

        zs = xs.aggregate(acc, agg_f, combine_scores)
        
    ratings = [(k,v['rating']) for k,v in zs.items()]
    
    for player, rating in sorted(ratings, key=lambda x: x[1], reverse=True)[:100]:
        print('{:<30}{}\t{}'.format(player,
                                    round(log2(rating+1), 1),
                                    ceil5(rating)))
    
    sc.stop()
# Out:
# MPQC                          13.3	9940
# Penguin (missile)             13.0	8210
# List of file systems          13.0	7975
# *Lisp                         12.8	7050
# Serpent (cipher)              12.4	5475
# DirectX Video Acceleration    12.3	4940
# John Cocke                    12.2	4635
# Bryce (software)              12.1	4315
# Fibonacci number              12.0	4090
# Deep Blue (chess computer)    12.0	4060
# Regular grid                  12.0	4005
# Luigi Federico Menabrea       11.9	3955
# BiiN                          11.9	3700
# Mach (kernel)                 11.8	3595
# DirectX                       11.7	3405
# Wolfram Mathematica           11.6	3215
# Hidden Markov model           11.6	3035
# YafaRay                       11.5	2970
# Intel                         11.5	2885
# Supercomputer                 11.5	2885
# Moore's law                   11.5	2865
# General-purpose computing on graphics processing units11.5	2865
# Lawrence Livermore National Laboratory11.5	2850
# Nvidia                        11.5	2815
# Mathematical finance          11.4	2685
# List of programming languages by type11.4	2655
# Ames Laboratory               11.3	2585
# PowerPC                       11.2	2365
# Index of computing articles   11.2	2335
# Operating system              11.1	2205
# Freescale Semiconductor       11.1	2205
# X86                           11.1	2195
# Atanasoff–Berry computer      11.1	2190
# Folding@home                  11.1	2180
# Itanium                       11.1	2130
# Gauss–Newton algorithm        11.0	2105
# Intel i860                    11.0	2065
# Thread (computing)            11.0	2045
# Graphics processing unit      11.0	2020
# Graphical model               10.9	1860
# SIMD                          10.8	1845
# Central processing unit       10.8	1835
# Pentium 4                     10.8	1810
# Monte Carlo method            10.8	1770
# Electric Sheep                10.8	1750
# Word (computer architecture)  10.7	1725
# VAX                           10.7	1720
# SETI@home                     10.7	1705
# Tejas and Jayhawk             10.7	1685
# ARM architecture              10.7	1680
# DEC Alpha                     10.7	1675
# SPARC                         10.7	1645
# Courant Institute of Mathematical Sciences10.7	1645
# Message Passing Interface     10.7	1630
# Computer multitasking         10.7	1625
# Radeon                        10.7	1620
# C (programming language)      10.7	1610
# David H. Bailey               10.7	1610
# GNU Octave                    10.6	1605
# Application-specific integrated circuit10.6	1580
# Description logic             10.6	1580
# Quadratic sieve               10.6	1580
# 8-bit                         10.6	1565
# Firefox                       10.6	1550
# Computer programming          10.6	1535
# Lock (computer science)       10.6	1525
# Microprocessor                10.6	1525
# Fortran                       10.6	1520
# CPU socket                    10.6	1515
# Apollo Guidance Computer      10.6	1515
# Matrix (mathematics)          10.6	1510
# Wikipedia:WikiProject Computing10.6	1510
# Digital art                   10.6	1500
# Vector processor              10.6	1500
# Quantum computing             10.5	1500
# 64-bit computing              10.5	1495
# Multi-core processor          10.5	1490
# VHDL                          10.5	1485
# Artificial intelligence       10.5	1470
# SuperH                        10.5	1455
# Cilk                          10.5	1440
# Memory management unit        10.5	1435
# Microcode                     10.5	1430
# Computer cluster              10.5	1430
# CUDA                          10.5	1420
# Distributed computing         10.5	1415
# David Patterson (computer scientist)10.5	1410
# Simultaneous multithreading   10.5	1410
# Thread pool                   10.5	1405
# MilkDrop                      10.4	1400
# Superscalar processor         10.4	1375
# Rendering (computer graphics) 10.4	1370
# 4-bit                         10.4	1365
# CPU cache                     10.4	1365
# Protein folding               10.4	1365
# Fractint                      10.4	1365
# Process (computing)           10.4	1350
# Field-programmable gate array 10.4	1325
# Apophysis (software)          10.4	1315
# Scalability                   10.4	1315

# %% [markdown]
# ### Part C - Page Rank

# %%
import re
import sys
from operator import add

from pyspark.sql import SparkSession

# %%
def computeContribs(urls, rank):
    """Calculates URL contributions to the rank of other URLs."""
    num_urls = len(urls)
    for url in urls:
        yield (url, rank / num_urls)

def parseNeighbors(urls):
    """Parses a urls pair string into urls pair."""
    parts = re.split(r'\s+', urls)
    return parts[0], parts[1]

# %%
try:
    sc.stop()
except:
    try:
        spark.stop()
    except:
        pass

if __name__ == "__main__":
    if len(sys.argv) != 3:
        print("Usage: pagerank <file> <iterations>", file=sys.stderr)
        sys.exit(-1)

    print("WARN: This is a naive implementation of PageRank and is given as an example!\n" +
          "Please refer to PageRank implementation provided by graphx",
          file=sys.stderr)

    # Initialize the spark context.
    spark = SparkSession.builder.appName("PythonPageRank").getOrCreate()
    
    lines = spark.read.text("pagerank_data.txt").rdd.map(lambda r: r[0])
    links = lines.map(lambda urls: parseNeighbors(urls)).distinct().groupByKey().cache()
    ranks = links.map(lambda url_neighbors: (url_neighbors[0], 1.0))
    
    for iteration in range(10):
        # Calculates URL contributions to the rank of other URLs.
        contribs = links.join(ranks).flatMap(
            lambda url_urls_rank: computeContribs(url_urls_rank[1][0], url_urls_rank[1][1]))

        # Re-calculates URL ranks based on neighbor contributions.
        ranks = contribs.reduceByKey(add).mapValues(lambda rank: rank * 0.85 + 0.15)
    
    for (link, rank) in ranks.collect():
        print("%s has rank: %s." % (link, rank))
    
    spark.stop()
# Out:
# WARN: This is a naive implementation of PageRank and is given as an example!
# Please refer to PageRank implementation provided by graphx
# 2 has rank: 0.7539975652935547.
# 3 has rank: 0.7539975652935547.
# 1 has rank: 1.7380073041193354.
# 4 has rank: 0.7539975652935547.

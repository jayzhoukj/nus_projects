# %% [markdown]
# 1. numerical vs categorical variables
# 2. [np.correlate() ~ >0.6/0.7] --> for multicollinearity --> check pairwise correlation, then remove either variables to reduce multicollinearity --> check pairwise correlation again for multicollinearity, then remove variables to reduce multicollinearity, repeat until all multicollinearity have been addressed.

# %% [markdown]
# ## Import Packages

# %%
import os
import pandas as pd, numpy as np, matplotlib.pyplot as plt, statsmodels.formula.api as smf
import seaborn as sns
os.getcwd()
# Out:
# 'C:\\Users\\Kai Jing\\Desktop\\NUS\\Business (Accountancy)\\NUS BAC\\Sem 2.1\\DAO2702 - Programming for Business Analytics\\Group Project\\data2'

# %% [markdown]
# ## Merging Data

# %%
df = pd.read_csv("January 2017.csv")
remaining_months = ['February','March','April','May','June','July','August','September','October','November','December']

for i in remaining_months:
    file_name = str(i) + ' 2017.csv'
    df_add = pd.read_csv(file_name)
    df = pd.concat([df,df_add])
df.reset_index(drop=True,inplace=True)
df
# Out:
# C:\Users\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   import sys
#                                                    access  accommodates  \
# 0                                                     NaN             2
# 1                                                     NaN             3
# 2                                                     NaN             2
# 3       Living room, open kitchen, balconies, bathroom...             4
# 4       Strong wifi, fully equipped kitchen, microwave...             4
# 5       There is access to the living room and kitchen...             2
# 6       You are free to use all in my house but treat ...             2
# 7       You are free to use all in my house but treat ...             2
# 8                           Bad, Kaffee und Tee ist frei.             2
# 9       Everything in the house (except the other priv...             2
# 10      Guest Access You'll have access to all the ame...             6
# 11      Asside from the bedroom, guests have a kitchen...             2
# 12      The complete apartment is available.  The owne...             4
# 13      Hi there, im living in a nice appartment with ...             1
# 14                                                    NaN             2
# 15      You are free to use all in my house but treat ...             2
# 16                                                    NaN             2
# 17                                                    NaN             2
# 18                                                    NaN             2
# 19                             Access to all areas/rooms.             4
# 20      Two open designed bedrooms with two toilets an...             4
# 21                                                    NaN             4
# 22                                                    NaN             4
# 23                                                    NaN             1
# 24                                                    NaN             2
# 25                                                    NaN             4
# 26      You will have access to the living room, kitch...             2
# 27      Private room, bathroom (seperate shower), livi...             2
# 28                                                    NaN             2
# 29      Strong wifi, fully equipped kitchen, dishwashe...            10
# ...                                                   ...           ...
# 201476                                                NaN             2
# 201477  You will have a direct access to Amsterdam cen...             3
# 201478                                                NaN             2
# 201479                                                NaN             2
# 201480                             Room, toilet, bathroom             2
# 201481                                                NaN             2
# 201482  You have access to the whole house with fully ...             4
# 201483  Complete kitchen with dishwasher and combi ove...             3
# 201484  A house with living arena, kitchen, bathroom, ...             5
# 201485         Big garden 50 m2,private room and bathroom             3
# 201486                                                NaN             2
# 201487  U can use the kitchen. There is a smal frigida...             2
# 201488           The whole apartment is for you to enjoy!             8
# 201489                                                NaN             4
# 201490  De woonboot ligt aan een flinke tuin welke vri...             2
# 201491                                                NaN             2
# 201492  You will have access to all rooms in my home: ...             6
# 201493  Kitchen, bathroom, toilets, lounge, Garden, be...             2
# 201494                                                NaN             1
# 201495                  Guests have access to all places.             5
# 201496                     Free Parking, Entire apartment             4
# 201497                                                NaN             2
# 201498                                                NaN             2
# 201499  All standard amenities are at your disposal: l...             4
# 201500                                                NaN             2
# 201501                           Toegang tot alle ruimtes             7
# 201502  As our guest, you have the right to use the ba...             2
# 201503                                                NaN             2
# 201504  U beschikt over de gehele woonboot en hoeft de...             2
# 201505                                                NaN             2
#
#                                                 amenities  availability_30  \
# 0       {TV,"Wireless Internet",Kitchen,"Free parking ...               24
# 1       {TV,"Wireless Internet",Kitchen,"Smoking allow...               20
# 2       {Internet,"Wireless Internet",Kitchen,"Free pa...                2
# 3       {TV,"Wireless Internet","Wheelchair accessible...                0
# 4       {Internet,"Wireless Internet",Kitchen,"Free pa...                2
# 5       {TV,"Cable TV",Internet,"Wireless Internet",Ki...               28
# 6       {TV,"Wireless Internet",Breakfast,"Free parkin...               28
# 7       {TV,Kitchen,Breakfast,"Free parking on street"...               28
# 8       {"Wireless Internet","Elevator in building",Sh...               29
# 9       {TV,Internet,"Wireless Internet",Kitchen,"Free...                0
# 10      {TV,"Cable TV",Internet,"Wireless Internet","W...               12
# 11      {TV,Internet,"Wheelchair accessible",Kitchen,"...                9
# 12      {Internet,"Wireless Internet","Wheelchair acce...               12
# 13      {TV,"Wireless Internet",Kitchen,"Free parking ...                1
# 14      {TV,"Wireless Internet",Kitchen,"Free parking ...                0
# 15      {TV,"Wireless Internet","Free parking on premi...               28
# 16      {TV,"Cable TV",Internet,"Wireless Internet","A...                0
# 17      {"Wireless Internet",Kitchen,"Free parking on ...               12
# 18      {"Wireless Internet",Kitchen,"Free parking on ...                0
# 19      {TV,"Cable TV",Internet,"Wireless Internet",Ki...                3
# 20      {TV,"Cable TV",Internet,"Wireless Internet",Ki...               22
# 21      {TV,"Cable TV",Internet,"Wireless Internet",Ki...                0
# 22      {Internet,"Wireless Internet","Wheelchair acce...               25
# 23      {"Wireless Internet",Kitchen,"Free parking on ...                0
# 24      {TV,"Wireless Internet","Air conditioning",Kit...                0
# 25      {TV,Internet,"Wireless Internet",Kitchen,"Free...               23
# 26      {TV,"Wireless Internet",Kitchen,"Smoking allow...                0
# 27      {TV,"Wireless Internet",Kitchen,"Free parking ...                1
# 28      {TV,"Wireless Internet",Kitchen,"Free parking ...               16
# 29      {Internet,"Wireless Internet",Kitchen,"Free pa...                2
# ...                                                   ...              ...
# 201476  {Internet,"Wireless Internet",Kitchen,"Free pa...               17
# 201477  {Internet,"Wireless Internet","Free parking on...                2
# 201478  {"Cable TV",Internet,"Wireless Internet",Kitch...                0
# 201479  {"Cable TV","Wireless Internet",Kitchen,"Free ...                1
# 201480  {TV,"Cable TV","Wireless Internet","Free parki...               15
# 201481  {TV,"Wireless Internet",Kitchen,"Free parking ...                0
# 201482  {TV,"Cable TV","Wireless Internet",Kitchen,"Fr...                4
# 201483  {TV,"Cable TV","Wireless Internet",Kitchen,Hea...                1
# 201484  {TV,"Cable TV",Internet,"Wireless Internet",Ki...                0
# 201485  {TV,Internet,"Wireless Internet","Free parking...               12
# 201486  {"Wireless Internet",Kitchen,"Free parking on ...                0
# 201487  {"Wireless Internet",Kitchen,"Free parking on ...               11
# 201488  {"Cable TV","Wireless Internet",Kitchen,"Free ...               22
# 201489  {TV,"Wireless Internet","Air conditioning",Kit...               27
# 201490  {TV,"Wireless Internet","Air conditioning",Kit...               27
# 201491  {Kitchen,"Free parking on premises",Heating,"F...                1
# 201492  {TV,"Cable TV","Wireless Internet",Kitchen,Hea...                0
# 201493  {TV,"Cable TV","Wireless Internet",Kitchen,"Fr...                0
# 201494  {"Wireless Internet",Kitchen,"Smoking allowed"...                1
# 201495  {TV,"Cable TV","Wireless Internet",Kitchen,"Fr...                3
# 201496  {TV,"Wireless Internet",Kitchen,"Free parking ...                6
# 201497  {TV,"Cable TV","Wireless Internet",Kitchen,"Fr...               16
# 201498  {TV,"Wireless Internet",Kitchen,"Free parking ...               10
# 201499  {TV,"Wireless Internet",Kitchen,"Pets allowed"...                0
# 201500  {"Wireless Internet",Kitchen,"Free parking on ...                0
# 201501  {TV,"Wireless Internet",Kitchen,"Free parking ...               18
# 201502  {"Wireless Internet",Kitchen,"Free parking on ...                4
# 201503  {TV,"Wireless Internet",Kitchen,"Smoking allow...               11
# 201504  {TV,"Wireless Internet","Air conditioning",Kit...               27
# 201505  {Kitchen,"Free parking on premises",Elevator,H...               25
#
#         availability_365  availability_60  availability_90  bathrooms  \
# 0                     58               52               58        1.0
# 1                    170               50               80        1.0
# 2                    182                2                2        1.0
# 3                      0                0                0        1.0
# 4                     78                2                2        1.0
# 5                    167               55               82        1.0
# 6                    178               58               88        1.0
# 7                    178               58               88        1.0
# 8                    179               59               89        1.0
# 9                     43                0                0        1.0
# 10                    53               25               35        1.5
# 11                   249               24               34        1.0
# 12                   161               21               25        1.0
# 13                    61               31               61        1.0
# 14                     0                0                0        1.0
# 15                   178               58               88        1.0
# 16                    27               17               27        1.0
# 17                    16               12               16        1.0
# 18                   278                4                5        1.0
# 19                     3                3                3        1.0
# 20                   168               48               78        2.0
# 21                     0                0                0        1.0
# 22                   141               51               81        1.0
# 23                   278                4                5        1.0
# 24                     0                0                0        1.0
# 25                    83               53               83        1.5
# 26                     0                0                0        1.0
# 27                     1                1                1        1.0
# 28                   153               41               66        1.0
# 29                   120                2                2        1.0
# ...                  ...              ...              ...        ...
# 201476               308               38               68        1.0
# 201477                61               31               60        1.0
# 201478                 0                0                0        1.0
# 201479                85                5               11        1.0
# 201480               348               43               73        1.0
# 201481                 0                0                0        1.0
# 201482                 4                4                4        1.5
# 201483                 1                1                1        1.5
# 201484               302                0               27        1.0
# 201485               279               15               36        1.0
# 201486                 0                0                0        1.0
# 201487               334               37               59        1.0
# 201488               143               49               72        2.0
# 201489               268               57               87        1.0
# 201490               178               57               87        1.0
# 201491                 2                2                2        1.0
# 201492                20                1               13        1.5
# 201493                41               10               40        1.0
# 201494                 4                4                4        2.0
# 201495                78               10               16        1.0
# 201496               190                6                9        1.0
# 201497                16               16               16        1.0
# 201498                10               10               10        1.0
# 201499                 0                0                0        1.0
# 201500                 0                0                0        1.0
# 201501               313               25               38        2.0
# 201502                39               21               38        1.0
# 201503                71               40               70        1.0
# 201504               362               57               87        1.0
# 201505                25               25               25        1.0
#
#              bed_type  bedrooms   ...     \
# 0            Real Bed       1.0   ...
# 1            Real Bed       1.0   ...
# 2            Real Bed       1.0   ...
# 3            Real Bed       1.0   ...
# 4            Real Bed       1.0   ...
# 5       Pull-out Sofa       1.0   ...
# 6            Real Bed       1.0   ...
# 7            Real Bed       1.0   ...
# 8            Real Bed       1.0   ...
# 9            Real Bed       1.0   ...
# 10           Real Bed       2.0   ...
# 11           Real Bed       1.0   ...
# 12           Real Bed       2.0   ...
# 13           Real Bed       1.0   ...
# 14           Real Bed       1.0   ...
# 15           Real Bed       1.0   ...
# 16           Real Bed       0.0   ...
# 17           Real Bed       1.0   ...
# 18           Real Bed       1.0   ...
# 19           Real Bed       2.0   ...
# 20           Real Bed       2.0   ...
# 21           Real Bed       2.0   ...
# 22           Real Bed       3.0   ...
# 23           Real Bed       1.0   ...
# 24              Futon       1.0   ...
# 25           Real Bed       3.0   ...
# 26           Real Bed       1.0   ...
# 27           Real Bed       1.0   ...
# 28           Real Bed       1.0   ...
# 29           Real Bed       2.0   ...
# ...               ...       ...   ...
# 201476       Real Bed       1.0   ...
# 201477       Real Bed       1.0   ...
# 201478       Real Bed       1.0   ...
# 201479       Real Bed       1.0   ...
# 201480       Real Bed       1.0   ...
# 201481       Real Bed       1.0   ...
# 201482       Real Bed       4.0   ...
# 201483       Real Bed       2.0   ...
# 201484       Real Bed       3.0   ...
# 201485       Real Bed       1.0   ...
# 201486       Real Bed       1.0   ...
# 201487       Real Bed       1.0   ...
# 201488       Real Bed       5.0   ...
# 201489       Real Bed       1.0   ...
# 201490       Real Bed       1.0   ...
# 201491       Real Bed       1.0   ...
# 201492       Real Bed       3.0   ...
# 201493       Real Bed       2.0   ...
# 201494       Real Bed       1.0   ...
# 201495       Real Bed       2.0   ...
# 201496       Real Bed       1.0   ...
# 201497       Real Bed       0.0   ...
# 201498       Real Bed       1.0   ...
# 201499       Real Bed       3.0   ...
# 201500       Real Bed       1.0   ...
# 201501       Real Bed       4.0   ...
# 201502       Real Bed       1.0   ...
# 201503       Real Bed       1.0   ...
# 201504       Real Bed       1.0   ...
# 201505       Real Bed       1.0   ...
#
#                                                     space  square_feet  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3       Welcome to our humble abode - 110 square meter...          NaN
# 4       You have a full private bedroom with LOCK, 1 d...          NaN
# 5       The bedroom is on the second floor. There are ...          NaN
# 6       Stylish room close to Ajax Arena (Ziggo Dome, ...          NaN
# 7       Stylish room close to Ajax Arena (Ziggo Dome, ...          NaN
# 8                                                     NaN          NaN
# 9       Everything in the house (except the other priv...          NaN
# 10      The Space This fully equipped apartment has 2 ...          NaN
# 11      Located in one of the most up and coming area'...          NaN
# 12      The apartment has been built 7 years ago. The ...          NaN
# 13                                                    NaN          NaN
# 14                                                    NaN          NaN
# 15      Stylish room close to Ajax Arena (Ziggo Dome, ...          NaN
# 16                                                    NaN          NaN
# 17                                                    NaN          NaN
# 18                                                    NaN          NaN
# 19      Split level apartment, with 1 living room, bal...          NaN
# 20      Modern Designed with the most beautiful view o...          NaN
# 21                                                    NaN          NaN
# 22                                                    NaN          NaN
# 23                                                    NaN          NaN
# 24                                                    NaN          NaN
# 25                                                    NaN          NaN
# 26      The flat is quite spacious with a big living r...          NaN
# 27      The maisonette/ town house is a split level ho...          NaN
# 28                                                    NaN          NaN
# 29      2 bedrooms, each can accommodate up to 4 peopl...          NaN
# ...                                                   ...          ...
# 201476  Jayanti is a coach, a writer and a massage the...          NaN
# 201477  We have bikes available to rent plus that we h...          NaN
# 201478                                                NaN          NaN
# 201479                                                NaN          NaN
# 201480  Description: - Quiet neighborhood close to Sch...          NaN
# 201481                                                NaN          NaN
# 201482                                                NaN          NaN
# 201483                              Very nice quiet area.          NaN
# 201484  A 170 m2 characteristic villa 25 minutes from ...          NaN
# 201485                            Big 30 m2,private entry          NaN
# 201486                                                NaN          NaN
# 201487  Deze plek heeft een geweldig uitzicht vanuit d...          NaN
# 201488  The apartment consists of a kitchen equipped w...          NaN
# 201489                                                NaN          NaN
# 201490  De complete woonboot heeft u tot uw beschikkin...          NaN
# 201491                                                NaN          NaN
# 201492  My house has 3 floors and 3 large bedrooms. My...          NaN
# 201493  Easy commute to Amsterdam Centrum. Quiet locat...          NaN
# 201494                                                NaN          NaN
# 201495  Our apartment in Zwanenburg is located on the ...          NaN
# 201496  The space We would love to welcome you. Our ap...          NaN
# 201497  The studio and furniture are very clean, you w...          NaN
# 201498                                                NaN          NaN
# 201499  House has 3 floors including the attic, so wal...          NaN
# 201500  Free parking. Close to Amsterdam, nature area ...          NaN
# 201501  Zeer ruim vrijstaande woning van alle gemakken...          NaN
# 201502  This simple and cozy room is perfect for one p...          NaN
# 201503                                                NaN          NaN
# 201504  De gehele woonboot staat tot u beschikking. Er...          NaN
# 201505                                                NaN          NaN
#
#                 state                                             street  \
# 0       Noord-Holland  Kikkenstein, Amsterdam-Zuidoost, Noord-Holland...
# 1       Noord-Holland  Kraaiennest, Amsterdam-Zuidoost, Noord-Holland...
# 2       Noord-Holland  Kleiburg, Amsterdam-Zuidoost, Noord-Holland 11...
# 3       Noord-Holland  Gouden Leeuw, Amsterdam Zuid-Oost, Noord-Holla...
# 4       Noord-Holland  Grubbehoeve, Amsterdam-Zuidoost, Noord-Holland...
# 5       Noord-Holland  Kantershof, Amsterdam Zuid-Oost, Noord-Holland...
# 6       Noord-Holland  Rosa Luxemburgstraat, Amsterdam-Zuidoost, Noor...
# 7       Noord-Holland  Rosa Luxemburgstraat, Amsterdam-Zuidoost, Noor...
# 8                  NH  Grubbehoeve, Amsterdam-Zuidoost, NH 1103 GZ, N...
# 9       North Holland  Clara Zetkinstraat, Amsterdam-Zuidoost, North ...
# 10      Noord-Holland  Harriët Freezerstraat, Amsterdam-Zuidoost, Noo...
# 11      Noord-Holland  Kleiburg, Amsterdam-Zuidoost, Noord-Holland 11...
# 12      Noord-Holland  Bijlmerdreef, Amsterdam-Zuidoost, Noord-Hollan...
# 13      Noord-Holland  Kleiburg, Amsterdam-Zuidoost, Noord-Holland 11...
# 14      Noord-Holland  Clara Zetkinstraat, Amsterdam Zuid-Oost, Noord...
# 15      Noord-Holland  Rosa Luxemburgstraat, Amsterdam-Zuidoost, Noor...
# 16      Noord-Holland  Karspeldreef, Amsterdam-Zuidoost, Noord-Hollan...
# 17      Noord-Holland  Kelbergen, Amsterdam-Zuidoost, Noord-Holland 1...
# 18      Noord-Holland  Kleiburg, Amsterdam-Zuidoost, Noord-Holland 11...
# 19      Noord-Holland  Bijlmerdreef, Amsterdam Zuid-Oost, Noord-Holla...
# 20      Noord-Holland  Kruitberghof, Amsterdam-Zuidoost, Noord-Hollan...
# 21      Noord-Holland  Kleiburg, Amsterdam-Zuidoost, Noord-Holland 11...
# 22      Noord-Holland  Kleiburg, Amsterdam-Zuidoost, Noord-Holland 11...
# 23      Noord-Holland  Kleiburg, Amsterdam-Zuidoost, Noord-Holland 11...
# 24      North Holland     Amsterdam-Zuidoost, North Holland, Netherlands
# 25      Noord-Holland  Kleiburg, Amsterdam-Zuidoost, Noord-Holland 11...
# 26      Noord-Holland  Grubbehoeve, Amsterdam-Zuidoost, Noord-Holland...
# 27      Noord-Holland  Bijlmerdreef, Amsterdam-Zuidoost, Noord-Hollan...
# 28      Noord-Holland  Kraaiennest, Amsterdam-Zuidoost, Noord-Holland...
# 29      Noord-Holland  Grubbehoeve, Amsterdam-Zuidoost, Noord-Holland...
# ...               ...                                                ...
# 201476  Noord-Holland              Amsterdam, Noord-Holland, Netherlands
# 201477  Noord-Holland              Amsterdam, Noord-Holland, Netherlands
# 201478  North Holland              Amsterdam, North Holland, Netherlands
# 201479  North Holland              Amsterdam, North Holland, Netherlands
# 201480  Noord-Holland              Amsterdam, Noord-Holland, Netherlands
# 201481  Noord-Holland              Amsterdam, Noord-Holland, Netherlands
# 201482  Noord-Holland              Amsterdam, Noord-Holland, Netherlands
# 201483  Noord-Holland              Amsterdam, Noord-Holland, Netherlands
# 201484             NH                         Amsterdam, NH, Netherlands
# 201485  North Holland              Amsterdam, North Holland, Netherlands
# 201486  Noord-Holland              Amsterdam, Noord-Holland, Netherlands
# 201487  Noord-Holland              Amsterdam, Noord-Holland, Netherlands
# 201488  Noord-Holland                 Diemen, Noord-Holland, Netherlands
# 201489  Noord-Holland     Amsterdam-Zuidoost, Noord-Holland, Netherlands
# 201490  Noord-Holland                 Uitdam, Noord-Holland, Netherlands
# 201491  Noord-Holland           Duivendrecht, Noord-Holland, Netherlands
# 201492  Noord-Holland                 Diemen, Noord-Holland, Netherlands
# 201493             NH                      Duivendrecht, NH, Netherlands
# 201494  Noord-Holland             Amstelveen, Noord-Holland, Netherlands
# 201495  Noord-Holland             Zwanenburg, Noord-Holland, Netherlands
# 201496  Noord-Holland             Amstelveen, Noord-Holland, Netherlands
# 201497             NH                        Amstelveen, NH, Netherlands
# 201498  Noord-Holland                 Diemen, Noord-Holland, Netherlands
# 201499  Noord-Holland              Amsterdam, Noord-Holland, Netherlands
# 201500  Noord-Holland              Landsmeer, Noord-Holland, Netherlands
# 201501        Utrecht                      Abcoude, Utrecht, Netherlands
# 201502  Noord-Holland           Badhoevedorp, Noord-Holland, Netherlands
# 201503  Noord-Holland                 Diemen, Noord-Holland, Netherlands
# 201504  Noord-Holland                 Uitdam, Noord-Holland, Netherlands
# 201505  Noord-Holland                 Diemen, Noord-Holland, Netherlands
#
#                                                   summary  \
# 0       My place is close to public transport. You’ll ...
# 1       We're a family home, we provide a very clean d...
# 2       Studio is closed to public transportation (met...
# 3       A home away from home - that's how we want you...
# 4       I ONLY ACCEPT GUESTS WITH GOVERNMENT IDs VERIF...
# 5       The House is adjacent to a park where you can ...
# 6       2 Shared Toilet, Bathroom with the host. The a...
# 7       My room is nearby shops , green environment . ...
# 8       Biete Zimmer für 2 Personen. Nur 25 min in die...
# 9       Stylish room close to the Bijlmer Arena (Ziggo...
# 10      Enjoy your stay at our beautiful apartment, wh...
# 11      Antiek/ modern interieur. Eigen douche, wc, ke...
# 12      Enjoy your stay in this wonderful apartment, l...
# 13      Mijn ruimte is vlakbij openbaar vervoer (4min)...
# 14      Stylish room close to the Bijlmer Arena (Ziggo...
# 15      Stylish room close to Ajax Arena (Ziggo Dome, ...
# 16      My place is located next to Kraaiennest Metro ...
# 17      My place is close to 5 Minutes away from the n...
# 18      This nice, new equipped apartment locates on t...
# 19      Split level apartment, 110 m², 2 bedrooms with...
# 20      Beautiful and extraordinary (over 110m2) spaci...
# 21      Mijn ruimte is vlakbij fantastisch uitzicht, r...
# 22      This nice, new equipped apartment locates on t...
# 23      This nice, new equipped apartment locates on t...
# 24      Studio, more pictures will follow. All new Mat...
# 25      This 96 square meter apartment is in one of th...
# 26      Spacious flat with big living-room, equipped k...
# 27      After a day in the crowded city you will find ...
# 28      We're a family home, we provide a very clean d...
# 29      I ONLY ACCEPT GUESTS WITH GOVERNMENT IDs VERIF...
# ...                                                   ...
# 201476  Jayantihouse is well known at airbnb and many ...
# 201477  It's a room in the 12th floor has a window on ...
# 201478  2-room (originally 4-room) appartment on outer...
# 201479  Het huis is gelegen in rustige buurt met openb...
# 201480  Well located room including Balcony. Room with...
# 201481  My place is close to RADION, Henk Sneevlietweg...
# 201482  Our 150m2 house is close to the airport (5 min...
# 201483  On the ground floor the kitchen and toilet, on...
# 201484  A unique beautifull house with sunny garden si...
# 201485  Big suite,private entry,private bathroom,own t...
# 201486  Large private room with a double bed in a very...
# 201487  The house is colorful and cosy decorated.  Fro...
# 201488  Want to enjoy sightseeing the picturesque cana...
# 201489  simple but efficient and nice!  up to 4 ppl + ...
# 201490  Prachtige locatie aan het meer  Uitzicht over ...
# 201491  Lovely ground floor appartment 52 square metre...
# 201492  Spacious, modern and light family house with a...
# 201493  Ground floor spacious apartment with a nice ba...
# 201494  This is a single room in a student campus. It ...
# 201495  A beautiful spacious apartment in Zwanenburg. ...
# 201496  My place is close to public transport. Its rea...
# 201497  It is a very nice and comfortable studio situa...
# 201498  You’ll love my place because it is a very quie...
# 201499  Beautiful and tastefully decorated house + sun...
# 201500  House with cosy feel. 140m2. Big garden. Free ...
# 201501  Vrijstaande woning 230 m2 op loopafstand van o...
# 201502  A friendly & warm home where peace will find y...
# 201503  Spacious 2 room apartment situated close to pu...
# 201504  Woonboot voorzien van woonkamer en keuken en s...
# 201505  An apartment on the 11th floor wit a marvellou...
#
#                                             thumbnail_url  \
# 0       https://a2.muscache.com/im/pictures/1abbe570-8...
# 1       https://a2.muscache.com/im/pictures/a1b7edaf-d...
# 2       https://a2.muscache.com/im/pictures/19fd9e15-3...
# 3       https://a1.muscache.com/im/pictures/90450862/9...
# 4       https://a2.muscache.com/im/pictures/02644cee-2...
# 5       https://a2.muscache.com/im/pictures/5cc6516a-a...
# 6       https://a2.muscache.com/im/pictures/d4e791fc-5...
# 7       https://a2.muscache.com/im/pictures/d21f07b3-6...
# 8       https://a2.muscache.com/im/pictures/7e36471e-c...
# 9       https://a1.muscache.com/im/pictures/66985029/6...
# 10      https://a2.muscache.com/im/pictures/ec866a0b-0...
# 11      https://a2.muscache.com/im/pictures/5b68c8d5-7...
# 12      https://a2.muscache.com/im/pictures/a7c0880f-5...
# 13      https://a2.muscache.com/im/pictures/45a91865-8...
# 14      https://a2.muscache.com/im/pictures/92665003/0...
# 15      https://a2.muscache.com/im/pictures/7c8f85a5-e...
# 16                                                    NaN
# 17      https://a2.muscache.com/im/pictures/6687a3f8-d...
# 18      https://a2.muscache.com/im/pictures/78c45c2b-7...
# 19      https://a2.muscache.com/im/pictures/dafbdf30-0...
# 20                                                    NaN
# 21      https://a2.muscache.com/im/pictures/a2706b85-b...
# 22      https://a2.muscache.com/im/pictures/2ab686e0-a...
# 23      https://a2.muscache.com/im/pictures/42bc56cd-b...
# 24      https://a2.muscache.com/im/pictures/a7eba16c-c...
# 25      https://a2.muscache.com/im/pictures/5c3895c1-8...
# 26      https://a2.muscache.com/im/pictures/25b71bb7-d...
# 27      https://a2.muscache.com/im/pictures/1fd753c6-9...
# 28      https://a2.muscache.com/im/pictures/2871e952-6...
# 29      https://a2.muscache.com/im/pictures/d06546cd-6...
# ...                                                   ...
# 201476  https://a0.muscache.com/im/pictures/8bfa9830-3...
# 201477  https://a0.muscache.com/im/pictures/5c549d1d-f...
# 201478                                                NaN
# 201479  https://a0.muscache.com/im/pictures/53275928/b...
# 201480  https://a0.muscache.com/im/pictures/61085042/0...
# 201481  https://a0.muscache.com/im/pictures/908025ed-7...
# 201482  https://a0.muscache.com/im/pictures/d2e4184d-1...
# 201483  https://a0.muscache.com/im/pictures/c308c150-8...
# 201484  https://a0.muscache.com/im/pictures/d6522011-3...
# 201485  https://a0.muscache.com/im/pictures/42001444/b...
# 201486  https://a0.muscache.com/im/pictures/c913d671-7...
# 201487  https://a0.muscache.com/im/pictures/bebb0465-d...
# 201488  https://a0.muscache.com/im/pictures/b1c8b6c7-c...
# 201489  https://a0.muscache.com/im/pictures/97f0b1c5-7...
# 201490  https://a0.muscache.com/im/pictures/11821b03-e...
# 201491  https://a0.muscache.com/im/pictures/f8ac2d20-6...
# 201492  https://a0.muscache.com/im/pictures/34c73dd9-c...
# 201493  https://a0.muscache.com/im/pictures/00a4623f-7...
# 201494  https://a0.muscache.com/im/pictures/6f1375c3-f...
# 201495  https://a0.muscache.com/im/pictures/4d7e6737-8...
# 201496  https://a0.muscache.com/im/pictures/a743ce68-c...
# 201497  https://a0.muscache.com/im/pictures/1a19db29-f...
# 201498  https://a0.muscache.com/im/pictures/a9ec1dfa-7...
# 201499  https://a0.muscache.com/im/pictures/5a6e9084-c...
# 201500  https://a0.muscache.com/im/pictures/c3983bfe-8...
# 201501  https://a0.muscache.com/im/pictures/4d152eb8-1...
# 201502  https://a0.muscache.com/im/pictures/0bc1e10b-0...
# 201503  https://a0.muscache.com/im/pictures/b5458de8-c...
# 201504  https://a0.muscache.com/im/pictures/3c762a85-a...
# 201505  https://a0.muscache.com/im/pictures/940dea88-1...
#
#                                                   transit weekly_price  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3       Metro is a 5 minute walk away and brings you i...      $415.00
# 4       ***** PLEASE READ CAREFULLY *****  +++ The clo...          NaN
# 5       within walking distance public transportation ...      $200.00
# 6                                                     NaN          NaN
# 7                                                     NaN          NaN
# 8       Ja Metro und Bus, 25 min in Amsterdamer Innens...          NaN
# 9       Great transportation. You can take the bus, me...          NaN
# 10                                                    NaN          NaN
# 11      5 min walking from the metro, that takes you d...          NaN
# 12      Metro is across the street, 3 minutes walking....      $615.00
# 13                               3min to Bus and metro 53          NaN
# 14                                                    NaN      $280.00
# 15      There is Ganzehoef metro on a walking distance...          NaN
# 16                                                    NaN          NaN
# 17                                                    NaN          NaN
# 18                                                    NaN          NaN
# 19      Metro station within 3 minutes walk (Metro Sta...      $393.00
# 20      Apartment is less then 20 minutes from Amsterd...          NaN
# 21                                                    NaN          NaN
# 22                                                    NaN          NaN
# 23                                                    NaN          NaN
# 24                                                    NaN          NaN
# 25                                                    NaN          NaN
# 26                                                    NaN          NaN
# 27      Metro (number 53) named Ganzenhoef Bus (named ...          NaN
# 28                                                    NaN          NaN
# 29      ***** PLEASE READ CAREFULLY *****  +++ The clo...          NaN
# ...                                                   ...          ...
# 201476  It is only 3 minutes walk to public transport....          NaN
# 201477  During the day you have tram 17 within 2 minut...          NaN
# 201478  Lightrail right in front of the appartment bui...      $400.00
# 201479                                                NaN          NaN
# 201480  Frequent tram (every 5-8 minutes) to center an...      $325.00
# 201481                                                NaN          NaN
# 201482  Tram 2 and its connections to other trams/metr...          NaN
# 201483  2 tram lines nearby. Both line 1 and 2 go to t...          NaN
# 201484     Tram 2, which goes to the centre of Amsterdam.          NaN
# 201485                             Tram 2,bus 145,bus 192          NaN
# 201486                                                NaN          NaN
# 201487  There is free parking in front of the house. B...          NaN
# 201488  Trams, busses, trains and ubers. The Schiphol ...          NaN
# 201489                                                NaN          NaN
# 201490                                                NaN          NaN
# 201491                                                NaN          NaN
# 201492  Tram 9 (directly to Amsterdam Centre) stop 400...          NaN
# 201493  Cycling is the best option in Amsterdam. Howev...          NaN
# 201494                                                NaN          NaN
# 201495  Trainstation Halfweg/Zwanenburg has an excelle...          NaN
# 201496  We are well located for seeing the sights in A...          NaN
# 201497                                                NaN          NaN
# 201498                                                NaN          NaN
# 201499  Train station Amsterdam Sloterdijk is a 7 minu...          NaN
# 201500  Best is by car (free parking) or by bike (25 m...          NaN
# 201501  In 10 minuten in Amsterdam met trein op loopaf...          NaN
# 201502  Destinations and time: // From our home to the...          NaN
# 201503                                                NaN          NaN
# 201504  Eigen auto heeft de voorkeur, maar fietsen kan...          NaN
# 201505                                                NaN          NaN
#
#                                            xl_picture_url  zipcode
# 0       https://a2.muscache.com/im/pictures/1abbe570-8...  1104 TW
# 1       https://a2.muscache.com/im/pictures/a1b7edaf-d...     1104
# 2       https://a2.muscache.com/im/pictures/19fd9e15-3...     1104
# 3       https://a1.muscache.com/im/pictures/90450862/9...  1103 KX
# 4       https://a2.muscache.com/im/pictures/02644cee-2...     1103
# 5       https://a2.muscache.com/im/pictures/5cc6516a-a...  1104 GE
# 6       https://a2.muscache.com/im/pictures/d4e791fc-5...     1103
# 7       https://a2.muscache.com/im/pictures/d21f07b3-6...     1103
# 8       https://a2.muscache.com/im/pictures/7e36471e-c...  1103 GZ
# 9       https://a1.muscache.com/im/pictures/66985029/6...  1103 DH
# 10      https://a2.muscache.com/im/pictures/ec866a0b-0...     1103
# 11      https://a2.muscache.com/im/pictures/5b68c8d5-7...  1104 EA
# 12      https://a2.muscache.com/im/pictures/a7c0880f-5...  1103 TX
# 13      https://a2.muscache.com/im/pictures/45a91865-8...     1104
# 14      https://a2.muscache.com/im/pictures/92665003/0...  1103 DH
# 15      https://a2.muscache.com/im/pictures/7c8f85a5-e...     1103
# 16                                                    NaN     1104
# 17      https://a2.muscache.com/im/pictures/6687a3f8-d...  1104 LH
# 18      https://a2.muscache.com/im/pictures/78c45c2b-7...     1104
# 19      https://a2.muscache.com/im/pictures/dafbdf30-0...  1103 JT
# 20                                                    NaN     1104
# 21      https://a2.muscache.com/im/pictures/a2706b85-b...  1104 EA
# 22      https://a2.muscache.com/im/pictures/2ab686e0-a...  1104 EA
# 23      https://a2.muscache.com/im/pictures/42bc56cd-b...     1104
# 24      https://a2.muscache.com/im/pictures/a7eba16c-c...      NaN
# 25      https://a2.muscache.com/im/pictures/5c3895c1-8...  1104 EA
# 26      https://a2.muscache.com/im/pictures/25b71bb7-d...     1103
# 27      https://a2.muscache.com/im/pictures/1fd753c6-9...  1103 TA
# 28      https://a2.muscache.com/im/pictures/2871e952-6...     1104
# 29      https://a2.muscache.com/im/pictures/d06546cd-6...     1103
# ...                                                   ...      ...
# 201476  https://a0.muscache.com/im/pictures/8bfa9830-3...  1069 PL
# 201477  https://a0.muscache.com/im/pictures/5c549d1d-f...      NaN
# 201478                                                NaN  1066 ML
# 201479  https://a0.muscache.com/im/pictures/53275928/b...  1069 PJ
# 201480  https://a0.muscache.com/im/pictures/61085042/0...  1060 RX
# 201481  https://a0.muscache.com/im/pictures/908025ed-7...  1066 HR
# 201482  https://a0.muscache.com/im/pictures/d2e4184d-1...  1066 WJ
# 201483  https://a0.muscache.com/im/pictures/c308c150-8...  1066 ST
# 201484  https://a0.muscache.com/im/pictures/d6522011-3...     1066
# 201485  https://a0.muscache.com/im/pictures/42001444/b...  1066 CW
# 201486  https://a0.muscache.com/im/pictures/c913d671-7...     1069
# 201487  https://a0.muscache.com/im/pictures/bebb0465-d...      NaN
# 201488  https://a0.muscache.com/im/pictures/b1c8b6c7-c...  1111 AL
# 201489  https://a0.muscache.com/im/pictures/97f0b1c5-7...     1103
# 201490  https://a0.muscache.com/im/pictures/11821b03-e...  1154 PS
# 201491  https://a0.muscache.com/im/pictures/f8ac2d20-6...  1115 XB
# 201492  https://a0.muscache.com/im/pictures/34c73dd9-c...  1111 CG
# 201493  https://a0.muscache.com/im/pictures/00a4623f-7...   1115CA
# 201494  https://a0.muscache.com/im/pictures/6f1375c3-f...      NaN
# 201495  https://a0.muscache.com/im/pictures/4d7e6737-8...     1161
# 201496  https://a0.muscache.com/im/pictures/a743ce68-c...  1181 CD
# 201497  https://a0.muscache.com/im/pictures/1a19db29-f...  1183 de
# 201498  https://a0.muscache.com/im/pictures/a9ec1dfa-7...  1112 KW
# 201499  https://a0.muscache.com/im/pictures/5a6e9084-c...  1014 AC
# 201500  https://a0.muscache.com/im/pictures/c3983bfe-8...  1121 PJ
# 201501  https://a0.muscache.com/im/pictures/4d152eb8-1...     1391
# 201502  https://a0.muscache.com/im/pictures/0bc1e10b-0...     1171
# 201503  https://a0.muscache.com/im/pictures/b5458de8-c...  1111 JT
# 201504  https://a0.muscache.com/im/pictures/3c762a85-a...  1154 PS
# 201505  https://a0.muscache.com/im/pictures/940dea88-1...  1111 MJ
#
# [201506 rows x 96 columns]

# %% [markdown]
# ## Selecting data variables to analyze

# %%
col_update = ['amenities','bathrooms','beds','calendar_last_scraped','id','monthly_price','neighbourhood_cleansed','price','property_type','review_scores_communication','review_scores_location','review_scores_rating','review_scores_value','room_type']
# len(col_update)
data = df['accommodates']
for i in col_update:
    data = pd.concat([data,df[i]],axis=1)

# %% [markdown]
# ## Checking empty cells

# %%
data.isna().sum()
# Out:
# accommodates                        0
# amenities                           0
# bathrooms                         224
# beds                              144
# calendar_last_scraped               0
# id                                  0
# monthly_price                  177575
# neighbourhood_cleansed              0
# price                               0
# property_type                       0
# review_scores_communication     28784
# review_scores_location          29125
# review_scores_rating            28512
# review_scores_value             29139
# room_type                           0
# dtype: int64

# %% [markdown]
# ## Dropping rows with NaN data (missing data)

# %%
df_col = list(data.columns)
# df_col, len(df_col)
for i in df_col:
    data = data[data[i].notna()]
data.isna().sum()
# Out:
# accommodates                   0
# amenities                      0
# bathrooms                      0
# beds                           0
# calendar_last_scraped          0
# id                             0
# monthly_price                  0
# neighbourhood_cleansed         0
# price                          0
# property_type                  0
# review_scores_communication    0
# review_scores_location         0
# review_scores_rating           0
# review_scores_value            0
# room_type                      0
# dtype: int64

# %%
data.reset_index(drop=True,inplace=True)
data
# Out:
#        accommodates                                          amenities  \
# 0                 4  {TV,"Wireless Internet","Wheelchair accessible...
# 1                 2  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 2                 4  {Internet,"Wireless Internet","Wheelchair acce...
# 3                 2  {TV,"Wireless Internet","Wheelchair accessible...
# 4                 4  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 5                 2  {"Wireless Internet",Kitchen,"Free parking on ...
# 6                 4  {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 7                 4  {TV,"Wireless Internet",Kitchen,"Free parking ...
# 8                 3  {TV,Internet,"Wireless Internet","Wheelchair a...
# 9                 5  {Internet,"Wireless Internet","Wheelchair acce...
# 10                1  {Internet,"Wireless Internet",Kitchen,Breakfas...
# 11                2  {TV,"Cable TV","Wireless Internet","Wheelchair...
# 12                2  {TV,"Cable TV","Wireless Internet",Kitchen,"Fr...
# 13                3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 14                4  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 15                2  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 16                4  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 17                5  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 18                2  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 19                2  {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 20                2  {"Cable TV","Wireless Internet",Kitchen,Gym,"B...
# 21                2  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 22                1  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 23                4  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 24                5  {"Cable TV",Internet,"Wireless Internet",Kitch...
# 25                3  {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 26                6  {TV,"Cable TV",Internet,"Wireless Internet","A...
# 27                2  {"Wireless Internet",Kitchen,"Free parking on ...
# 28                2  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 29                4  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# ...             ...                                                ...
# 22748             4  {Internet,"Wireless Internet","Wheelchair acce...
# 22749             2  {TV,"Cable TV","Wireless Internet","Air condit...
# 22750             4  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 22751             2  {"Wireless Internet","Wheelchair accessible",K...
# 22752             3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 22753             2  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 22754             2  {Internet,"Wireless Internet",Kitchen,Heating,...
# 22755             2  {TV,"Wireless Internet",Breakfast,Elevator,Hea...
# 22756             2  {TV,"Cable TV","Wireless Internet",Kitchen,"Bu...
# 22757             2  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 22758             4  {TV,"Wireless Internet",Kitchen,Heating,Washer...
# 22759             4  {Internet,"Wireless Internet",Kitchen,"Buzzer/...
# 22760             2  {"Wireless Internet",Kitchen,"Smoking allowed"...
# 22761             2  {TV,Internet,"Wireless Internet","Wheelchair a...
# 22762             4  {TV,"Cable TV",Internet,"Wireless Internet","W...
# 22763             2  {TV,Internet,"Wireless Internet","Wheelchair a...
# 22764             2  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 22765             2  {TV,"Cable TV","Wireless Internet",Kitchen,"Fr...
# 22766             2  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 22767             1  {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 22768             5  {TV,"Wireless Internet",Kitchen,"Free parking ...
# 22769             4  {"Wireless Internet",Kitchen,"Free parking on ...
# 22770             2  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 22771             5  {TV,"Cable TV",Internet,"Wireless Internet",Ki...
# 22772             4  {TV,Internet,"Wireless Internet",Kitchen,"Free...
# 22773             2  {TV,"Cable TV",Internet,"Wireless Internet","F...
# 22774             4  {"Wireless Internet",Kitchen,"Free parking on ...
# 22775             4  {"Wireless Internet",Kitchen,"Free parking on ...
# 22776             3  {Internet,"Wireless Internet","Wheelchair acce...
# 22777             2  {TV,"Cable TV","Wireless Internet","Free parki...
#
#        bathrooms  beds calendar_last_scraped        id monthly_price  \
# 0            1.0   2.0            2017-01-02   7131573     $1,460.00
# 1            1.0   2.0            2017-01-02   9115414       $600.00
# 2            1.0   2.0            2017-01-02  12023314     $2,060.00
# 3            1.0   1.0            2017-01-02   9038396     $1,000.00
# 4            1.0   2.0            2017-01-02   7627532     $1,125.00
# 5            1.0   1.0            2017-01-02   3719167       $995.00
# 6            1.5   2.0            2017-01-02   7880299     $1,350.00
# 7            1.0   2.0            2017-01-02  10662701     $1,800.00
# 8            1.0   2.0            2017-01-02   9880934     $1,278.00
# 9            0.5   3.0            2017-01-02   7706472     $2,520.00
# 10           1.0   1.0            2017-01-02   4983904       $400.00
# 11           1.0   1.0            2017-01-02   5998167     $1,600.00
# 12           1.0   1.0            2017-01-02   1358042     $1,350.00
# 13           1.5   2.0            2017-01-02  10172405     $3,000.00
# 14           1.0   2.0            2017-01-02   6484413     $3,500.00
# 15           1.0   1.0            2017-01-02   8583977       $880.00
# 16           1.0   6.0            2017-01-02   8811789     $6,900.00
# 17           1.0   4.0            2017-01-02   6417023     $1,800.00
# 18           1.5   1.0            2017-01-02   3462884     $1,590.00
# 19           1.0   1.0            2017-01-02   4773154     $1,200.00
# 20           1.0   2.0            2017-01-02   3753071     $1,500.00
# 21           1.0   2.0            2017-01-02   9192196       $850.00
# 22           1.0   1.0            2017-01-02  10502510       $751.00
# 23           1.0   4.0            2017-01-02   3896355     $1,249.00
# 24           1.5   5.0            2017-01-02   3259374     $2,500.00
# 25           1.0   2.0            2017-01-02    761411       $930.00
# 26           2.0   6.0            2017-01-02   2550665     $3,500.00
# 27           1.0   2.0            2017-01-02   3710782     $1,585.00
# 28           1.0   1.0            2017-01-02   5216536     $2,352.00
# 29           1.0   4.0            2017-01-02   5707655     $1,407.00
# ...          ...   ...                   ...       ...           ...
# 22748        1.0   2.0            2017-12-04  10337148     $3,000.00
# 22749        1.0   2.0            2017-12-04   1859255     $1,800.00
# 22750        1.0   2.0            2017-12-04   9197369     $4,450.00
# 22751        1.5   1.0            2017-12-04    546215     $1,500.00
# 22752        1.0   2.0            2017-12-04  10988339     $2,500.00
# 22753        1.0   1.0            2017-12-04   9194610     $1,450.00
# 22754        1.0   1.0            2017-12-04   1102424     $1,250.00
# 22755        1.0   1.0            2017-12-04   2763386     $1,252.00
# 22756        1.0   1.0            2017-12-04    866523     $1,197.00
# 22757        1.5   1.0            2017-12-04   8304921     $1,500.00
# 22758        1.0   2.0            2017-12-04   5156433     $1,250.00
# 22759        1.0   2.0            2017-12-04   5869218     $2,300.00
# 22760        1.0   1.0            2017-12-04   2761156     $1,100.00
# 22761        1.0   1.0            2017-12-04   1541016       $980.00
# 22762        1.0   2.0            2017-12-04   7672411     $4,500.00
# 22763        1.0   1.0            2017-12-04   3786429     $1,386.00
# 22764        1.0   1.0            2017-12-04   4981487     $1,250.00
# 22765        1.0   1.0            2017-12-04   3837731     $1,700.00
# 22766        1.0   2.0            2017-12-04   1085426     $1,250.00
# 22767        1.0   1.0            2017-12-04   1232131       $756.00
# 22768        1.5   5.0            2017-12-04   2670363     $2,000.00
# 22769        1.0   3.0            2017-12-04   8339007     $2,800.00
# 22770        1.0   1.0            2017-12-04    884329     $2,600.00
# 22771        1.0   3.0            2017-12-04   5362958     $9,500.00
# 22772        1.0   2.0            2017-12-04   5887152     $2,562.00
# 22773        1.0   2.0            2017-12-04   5012728       $995.00
# 22774        1.0   2.0            2017-12-04  13940956     $1,800.00
# 22775        1.0   4.0            2017-12-04   8041012     $1,900.00
# 22776        1.0   3.0            2017-12-04   4140273     $2,500.00
# 22777        1.0   1.0            2017-12-04   4864384       $995.00
#
#        neighbourhood_cleansed    price    property_type  \
# 0                Bijlmer-Oost   $50.00        Apartment
# 1                Bijlmer-Oost   $40.00            House
# 2                Bijlmer-Oost   $99.00        Apartment
# 3                Bijlmer-Oost   $55.00        Apartment
# 4                Bijlmer-Oost   $99.00        Apartment
# 5                Bijlmer-Oost   $46.00            House
# 6                Bijlmer-Oost   $85.00        Apartment
# 7                Bijlmer-Oost  $100.00        Apartment
# 8                Bijlmer-Oost   $65.00        Apartment
# 9                Bijlmer-Oost  $109.00        Apartment
# 10               Bijlmer-Oost   $22.00            House
# 11               Bijlmer-Oost   $65.00        Apartment
# 12                 Noord-Oost   $75.00             Boat
# 13                 Noord-Oost  $170.00            House
# 14                 Noord-Oost  $175.00        Apartment
# 15                 Noord-Oost   $57.00        Apartment
# 16                 Noord-Oost  $195.00            House
# 17                 Noord-Oost   $75.00            House
# 18                 Noord-Oost   $54.00        Apartment
# 19                 Noord-Oost   $65.00        Apartment
# 20                 Noord-Oost   $75.00        Apartment
# 21                 Noord-Oost   $65.00        Apartment
# 22                 Noord-Oost   $37.00        Apartment
# 23                 Noord-Oost   $64.00        Apartment
# 24                 Noord-Oost  $140.00            House
# 25                 Noord-Oost   $48.00        Apartment
# 26                 Noord-Oost  $170.00            House
# 27                 Noord-Oost   $90.00             Boat
# 28                 Noord-Oost  $112.00             Loft
# 29                 Noord-Oost   $85.00      Condominium
# ...                       ...      ...              ...
# 22748             Slotervaart  $175.00        Apartment
# 22749             Slotervaart   $75.00  Bed & Breakfast
# 22750             Slotervaart  $225.00        Townhouse
# 22751             Slotervaart  $105.00        Apartment
# 22752             Slotervaart  $150.00        Apartment
# 22753             Slotervaart   $85.00        Townhouse
# 22754             Slotervaart  $105.00        Apartment
# 22755             Slotervaart   $58.00  Bed & Breakfast
# 22756             Slotervaart   $80.00        Apartment
# 22757             Slotervaart   $75.00        Apartment
# 22758             Slotervaart   $75.00        Apartment
# 22759             Slotervaart  $125.00        Apartment
# 22760             Slotervaart   $50.00  Bed & Breakfast
# 22761             Slotervaart   $59.00        Apartment
# 22762             Slotervaart  $250.00        Apartment
# 22763             Slotervaart   $80.00        Apartment
# 22764                  Osdorp   $69.00        Apartment
# 22765                  Osdorp   $90.00        Apartment
# 22766                  Osdorp   $55.00        Apartment
# 22767                  Osdorp   $38.00        Apartment
# 22768                  Osdorp  $109.00            House
# 22769  De Aker - Nieuw Sloten  $100.00            House
# 22770  De Aker - Nieuw Sloten  $115.00        Apartment
# 22771  De Aker - Nieuw Sloten  $375.00            House
# 22772  De Aker - Nieuw Sloten   $85.00            House
# 22773  De Aker - Nieuw Sloten   $59.00            House
# 22774  De Aker - Nieuw Sloten  $119.00            Cabin
# 22775  De Aker - Nieuw Sloten   $76.00        Apartment
# 22776  De Aker - Nieuw Sloten   $80.00           Chalet
# 22777  De Aker - Nieuw Sloten   $59.00            House
#
#        review_scores_communication  review_scores_location  \
# 0                             10.0                     8.0
# 1                             10.0                     7.0
# 2                             10.0                     9.0
# 3                              7.0                     4.0
# 4                             10.0                     9.0
# 5                              9.0                     8.0
# 6                             10.0                     8.0
# 7                             10.0                     9.0
# 8                             10.0                     8.0
# 9                             10.0                     8.0
# 10                            10.0                     8.0
# 11                             9.0                     8.0
# 12                            10.0                     9.0
# 13                            10.0                    10.0
# 14                            10.0                     9.0
# 15                             9.0                     9.0
# 16                            10.0                    10.0
# 17                            10.0                     9.0
# 18                            10.0                     9.0
# 19                             9.0                     9.0
# 20                            10.0                     9.0
# 21                            10.0                    10.0
# 22                             9.0                     9.0
# 23                             9.0                     9.0
# 24                            10.0                    10.0
# 25                            10.0                     9.0
# 26                            10.0                    10.0
# 27                            10.0                     9.0
# 28                            10.0                     9.0
# 29                            10.0                     9.0
# ...                            ...                     ...
# 22748                         10.0                    10.0
# 22749                         10.0                     9.0
# 22750                         10.0                     8.0
# 22751                         10.0                     8.0
# 22752                         10.0                     7.0
# 22753                         10.0                     9.0
# 22754                         10.0                    10.0
# 22755                         10.0                     9.0
# 22756                         10.0                    10.0
# 22757                         10.0                     9.0
# 22758                         10.0                     9.0
# 22759                         10.0                     8.0
# 22760                         10.0                     9.0
# 22761                         10.0                     8.0
# 22762                         10.0                    10.0
# 22763                         10.0                     9.0
# 22764                         10.0                     9.0
# 22765                         10.0                     9.0
# 22766                         10.0                     8.0
# 22767                         10.0                     9.0
# 22768                         10.0                     9.0
# 22769                         10.0                     9.0
# 22770                         10.0                     9.0
# 22771                         10.0                    10.0
# 22772                         10.0                     9.0
# 22773                         10.0                     9.0
# 22774                         10.0                     9.0
# 22775                         10.0                     9.0
# 22776                         10.0                     9.0
# 22777                         10.0                     9.0
#
#        review_scores_rating  review_scores_value        room_type
# 0                      92.0                  9.0     Private room
# 1                     100.0                  9.0     Private room
# 2                      98.0                 10.0  Entire home/apt
# 3                      60.0                  5.0  Entire home/apt
# 4                     100.0                 10.0  Entire home/apt
# 5                      90.0                  9.0     Private room
# 6                      94.0                 10.0  Entire home/apt
# 7                      93.0                  9.0  Entire home/apt
# 8                      89.0                 10.0  Entire home/apt
# 9                      89.0                  9.0  Entire home/apt
# 10                     85.0                  8.0     Private room
# 11                     92.0                  9.0  Entire home/apt
# 12                     98.0                 10.0  Entire home/apt
# 13                     80.0                 10.0  Entire home/apt
# 14                     97.0                  9.0  Entire home/apt
# 15                     79.0                  8.0     Private room
# 16                    100.0                 10.0  Entire home/apt
# 17                    100.0                 10.0  Entire home/apt
# 18                     96.0                  9.0     Private room
# 19                     98.0                  9.0  Entire home/apt
# 20                     96.0                 10.0  Entire home/apt
# 21                     98.0                 10.0  Entire home/apt
# 22                     85.0                  9.0     Private room
# 23                     87.0                  9.0  Entire home/apt
# 24                    100.0                 10.0  Entire home/apt
# 25                     95.0                  9.0     Private room
# 26                     94.0                  9.0  Entire home/apt
# 27                    100.0                 10.0  Entire home/apt
# 28                     95.0                  9.0  Entire home/apt
# 29                     93.0                  9.0     Private room
# ...                     ...                  ...              ...
# 22748                 100.0                 10.0  Entire home/apt
# 22749                  98.0                 10.0     Private room
# 22750                 100.0                 10.0  Entire home/apt
# 22751                  97.0                  9.0  Entire home/apt
# 22752                  90.0                  9.0  Entire home/apt
# 22753                  98.0                  9.0     Private room
# 22754                 100.0                 10.0  Entire home/apt
# 22755                  98.0                 10.0     Private room
# 22756                 100.0                 10.0  Entire home/apt
# 22757                  99.0                  9.0     Private room
# 22758                  96.0                 10.0  Entire home/apt
# 22759                  98.0                  9.0  Entire home/apt
# 22760                  94.0                  9.0     Private room
# 22761                  97.0                  9.0     Private room
# 22762                 100.0                 10.0  Entire home/apt
# 22763                  94.0                  9.0  Entire home/apt
# 22764                  97.0                 10.0     Private room
# 22765                 100.0                 10.0  Entire home/apt
# 22766                  95.0                  9.0     Private room
# 22767                  96.0                 10.0     Private room
# 22768                  94.0                 10.0  Entire home/apt
# 22769                  98.0                  9.0  Entire home/apt
# 22770                  98.0                 10.0     Private room
# 22771                 100.0                 10.0  Entire home/apt
# 22772                  95.0                  9.0     Private room
# 22773                  97.0                 10.0     Private room
# 22774                  94.0                 10.0  Entire home/apt
# 22775                  94.0                  9.0  Entire home/apt
# 22776                  93.0                  8.0     Private room
# 22777                  96.0                 10.0     Private room
#
# [22778 rows x 15 columns]

# %% [markdown]
# ## Creating average review score base on the review scores of communication, location, rating and value

# %%
data['review_scores_rating'] = data['review_scores_rating'].apply(lambda x: x/10)
data['review_score_average'] = data[['review_scores_communication','review_scores_location','review_scores_rating','review_scores_value']].mean(axis=1)
data.drop(['review_scores_communication','review_scores_location','review_scores_rating','review_scores_value'],inplace=True,axis=1)

# %% [markdown]
# ## Converting prices to integers

# %%
data['price'] = data['price'].apply(lambda x: x.replace(',',''))
data['price'] = data['price'].apply(lambda x: int(x[1:-3]))
data['monthly_price'] = data['monthly_price'].apply(lambda x: x.replace(',',''))
data['monthly_price'] = data['monthly_price'].apply(lambda x: int(x[1:-3]))

# %% [markdown]
# ##  Creating amenities count

# %%
data['amenities_count'] = data['amenities'].str.split(',').apply(lambda x: len(x))
data.drop('amenities',inplace=True,axis=1)

# %% [markdown]
# ## Extracting month of data extracted

# %%
data['calendar_last_scraped'] = pd.to_datetime(data['calendar_last_scraped'], format='%Y-%m-%d')
data['month_scraped'] = data['calendar_last_scraped'].dt.strftime('%b')
data.drop('calendar_last_scraped',inplace=True,axis=1)

# %%
# Checking for correctness of amenities_count
# for i in range(len(data)):
#     data.loc[i,'amenities_count2'] = len(data['amenities'][i].split(','))
# print(sum(data['amenities_count'] == data['amenities_count2']))
# data.drop('amenities_count2',inplace=True,axis=1)

# %% [markdown]
# ## Further data cleaning

# %%
#group by id
data_by_id = data.groupby('id')

#finding means of numerical variables
data2 = data_by_id[['price']].mean()
data2['mean_monthly_price'] = data_by_id[['monthly_price']].mean()
data2['mean_amenities'] = data_by_id[['amenities_count']].mean()
data2['mean_accommodates'] = data_by_id[['accommodates']].mean()
data2['mean_bathrooms'] = data_by_id[['bathrooms']].mean()
data2['mean_beds'] = data_by_id[['beds']].mean()
data2['mean_reviews'] = data_by_id[['review_score_average']].mean()

#extracting last month of catergorical variables
data2['neighbourhood'] = data_by_id[['neighbourhood_cleansed']].last()
data2['property_type'] = data_by_id[['property_type']].last()
data2['room_type'] = data_by_id[['room_type']].last()

data2.reset_index(inplace=True)
data2.head()
# Out:
#       id       price  mean_monthly_price  mean_amenities  mean_accommodates  \
# 0   2818   71.083333              1500.0       25.000000                2.0
# 1   3209  132.166667              2000.0       20.583333                4.0
# 2   8061  135.000000              2400.0       17.000000                2.0
# 3  27886  145.000000              2500.0       17.666667                2.0
# 4  29051   55.000000              1435.0       11.000000                1.0
#
#    mean_bathrooms  mean_beds  mean_reviews  \
# 0             1.5        2.0      9.675000
# 1             1.0        2.0      9.364583
# 2             1.0        2.0     10.000000
# 3             1.0        1.0      9.975000
# 4             1.0        1.0      9.610000
#
#                             neighbourhood property_type        room_type
# 0  Oostelijk Havengebied - Indische Buurt     Apartment     Private room
# 1                              Westerpark   Condominium  Entire home/apt
# 2                  De Baarsjes - Oud-West     Apartment  Entire home/apt
# 3                            Centrum-West     Apartment     Private room
# 4                            Centrum-West         House     Private room

# %%
data2.to_csv('data.csv',index=False)

# %% [markdown]
# ## Backward Stepwise Model

# %%
def back_sel(data, y, current_predictors):
    #print(len(current_predictors), current_predictors)
    aic_k_best = 1e+8
    for predictor_to_remove in current_predictors:
        new_predictors = current_predictors.copy()
        new_predictors.remove(predictor_to_remove)
        if new_predictors:
            formula = y + ' ~ ' + ' + '.join(new_predictors)
        else:
            formula = y + ' ~ 1'
        model = smf.ols(formula, data=data).fit()
        #print('\t', model.aic, new_predictors)
        if model.aic <= aic_k_best:
            aic_k_best = model.aic
            model_k_best = model
            predictors_k_best = new_predictors
    #print('best: ', model_k_best.aic, predictors_k_best)
    return model_k_best, predictors_k_best

# %%
current_predictors = set(list(data2.columns))
current_predictors.remove('id')
current_predictors.remove('price')
model_full = smf.ols('price ~ ' + ' + '.join(current_predictors), data=data2).fit()
aic_bwd = model_full.aic
model_bwd = model_full
predictors_bwd = current_predictors

# %%
while len(current_predictors) > 0:
    model, current_predictors = back_sel(data2, 'price', current_predictors)
    print(len(current_predictors), model.aic, current_predictors)
    if model.aic <= aic_bwd:
        aic_bwd = model.aic
        model_bwd = model
        predictors_bwd = current_predictors
print('Best Model: ', model_bwd.aic, predictors_bwd)
# Out:
# 8 28159.677177615267 {'mean_reviews', 'mean_amenities', 'neighbourhood', 'mean_accommodates', 'mean_monthly_price', 'room_type', 'property_type', 'mean_bathrooms'}
# 7 28174.174415432535 {'mean_reviews', 'neighbourhood', 'mean_accommodates', 'mean_monthly_price', 'room_type', 'property_type', 'mean_bathrooms'}
# 6 28197.586033379936 {'mean_accommodates', 'mean_monthly_price', 'neighbourhood', 'room_type', 'property_type', 'mean_bathrooms'}
# 5 28222.30488955941 {'mean_accommodates', 'mean_monthly_price', 'neighbourhood', 'room_type', 'mean_bathrooms'}
# 4 28275.361082984025 {'mean_accommodates', 'mean_monthly_price', 'neighbourhood', 'mean_bathrooms'}
# 3 28364.39978195633 {'mean_accommodates', 'mean_monthly_price', 'mean_bathrooms'}
# 2 28465.324148785134 {'mean_accommodates', 'mean_monthly_price'}
# 1 28766.29011796062 {'mean_monthly_price'}
# 0 31061.761481365756 set()
# Best Model:  28153.027289354613 {'mean_beds', 'mean_reviews', 'mean_amenities', 'neighbourhood', 'mean_accommodates', 'mean_monthly_price', 'room_type', 'property_type', 'mean_bathrooms'}

# %%
model_bwd.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     122.9
# Date:                Wed, 21 Nov 2018   Prob (F-statistic):               0.00
# Time:                        20:17:47   Log-Likelihood:                -14032.
# No. Observations:                2695   AIC:                         2.815e+04
# Df Residuals:                    2650   BIC:                         2.842e+04
# Df Model:                          44
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept                                                -110.3247     23.760     -4.643      0.000    -156.916     -63.734
# neighbourhood[T.Bijlmer-Oost]                              -4.8886     19.283     -0.254      0.800     -42.699      32.922
# neighbourhood[T.Bos en Lommer]                             16.5485     16.270      1.017      0.309     -15.355      48.452
# neighbourhood[T.Buitenveldert - Zuidas]                    14.0049     17.588      0.796      0.426     -20.482      48.492
# neighbourhood[T.Centrum-Oost]                              38.9692     16.058      2.427      0.015       7.481      70.457
# neighbourhood[T.Centrum-West]                              37.5879     15.991      2.351      0.019       6.232      68.944
# neighbourhood[T.De Aker - Nieuw Sloten]                    -7.0836     20.266     -0.350      0.727     -46.822      32.655
# neighbourhood[T.De Baarsjes - Oud-West]                    20.9572     15.947      1.314      0.189     -10.313      52.227
# neighbourhood[T.De Pijp - Rivierenbuurt]                   23.1829     16.001      1.449      0.147      -8.192      54.558
# neighbourhood[T.Gaasperdam - Driemond]                     -8.7157     21.800     -0.400      0.689     -51.462      34.031
# neighbourhood[T.Geuzenveld - Slotermeer]                    8.2500     17.948      0.460      0.646     -26.943      43.443
# neighbourhood[T.IJburg - Zeeburgereiland]                   8.6944     17.403      0.500      0.617     -25.430      42.819
# neighbourhood[T.Noord-Oost]                                -3.0141     18.025     -0.167      0.867     -38.358      32.330
# neighbourhood[T.Noord-West]                                -1.0396     18.326     -0.057      0.955     -36.975      34.896
# neighbourhood[T.Oostelijk Havengebied - Indische Buurt]    23.5512     16.268      1.448      0.148      -8.348      55.451
# neighbourhood[T.Osdorp]                                    -5.2681     20.715     -0.254      0.799     -45.887      35.351
# neighbourhood[T.Oud-Noord]                                  4.6909     16.636      0.282      0.778     -27.930      37.312
# neighbourhood[T.Oud-Oost]                                  20.9020     16.229      1.288      0.198     -10.921      52.725
# neighbourhood[T.Slotervaart]                               26.4917     17.246      1.536      0.125      -7.326      60.309
# neighbourhood[T.Watergraafsmeer]                            6.9846     16.708      0.418      0.676     -25.777      39.746
# neighbourhood[T.Westerpark]                                21.0923     16.159      1.305      0.192     -10.593      52.777
# neighbourhood[T.Zuid]                                      26.2909     16.144      1.629      0.104      -5.366      57.947
# room_type[T.Private room]                                 -16.7785      2.431     -6.903      0.000     -21.544     -12.013
# room_type[T.Shared room]                                  -53.4875     17.268     -3.097      0.002     -87.348     -19.627
# property_type[T.Bed & Breakfast]                            0.3240      4.739      0.068      0.946      -8.969       9.617
# property_type[T.Boat]                                      17.1519      4.743      3.617      0.000       7.852      26.451
# property_type[T.Bungalow]                                   3.8478     45.567      0.084      0.933     -85.503      93.199
# property_type[T.Cabin]                                    -15.1317     18.718     -0.808      0.419     -51.835      21.572
# property_type[T.Chalet]                                     3.1750     32.323      0.098      0.922     -60.206      66.556
# property_type[T.Condominium]                               -4.5057      8.504     -0.530      0.596     -21.181      12.170
# property_type[T.Dorm]                                      46.8727     48.329      0.970      0.332     -47.894     141.640
# property_type[T.Earth House]                               29.9457     44.827      0.668      0.504     -57.953     117.844
# property_type[T.Guest suite]                              -28.6958     25.981     -1.104      0.269     -79.641      22.249
# property_type[T.House]                                     17.2266      3.263      5.279      0.000      10.828      23.625
# property_type[T.Loft]                                       6.7076      7.992      0.839      0.401      -8.963      22.378
# property_type[T.Other]                                    -28.8671     13.181     -2.190      0.029     -54.712      -3.022
# property_type[T.Serviced apartment]                       -20.4536     44.700     -0.458      0.647    -108.104      67.197
# property_type[T.Townhouse]                                  3.7351      9.461      0.395      0.693     -14.817      22.287
# property_type[T.Villa]                                     21.0004     31.805      0.660      0.509     -41.365      83.366
# mean_beds                                                   3.4505      1.182      2.919      0.004       1.132       5.769
# mean_reviews                                                8.5571      1.950      4.389      0.000       4.734      12.380
# mean_amenities                                              0.6331      0.163      3.873      0.000       0.313       0.954
# mean_accommodates                                          10.5388      1.237      8.517      0.000       8.112      12.965
# mean_monthly_price                                          0.0239      0.001     33.811      0.000       0.022       0.025
# mean_bathrooms                                             31.6652      3.132     10.111      0.000      25.524      37.806
# ==============================================================================
# Omnibus:                     1185.700   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            79590.491
# Skew:                           1.236   Prob(JB):                         0.00
# Kurtosis:                      29.508   Cond. No.                     2.66e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.66e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data2[list(predictors_bwd)].corr()
# Out:
#                     mean_beds  mean_reviews  mean_amenities  \
# mean_beds            1.000000     -0.034184        0.176819
# mean_reviews        -0.034184      1.000000        0.130053
# mean_amenities       0.176819      0.130053        1.000000
# mean_accommodates    0.838515     -0.050292        0.155906
# mean_monthly_price   0.502365      0.087380        0.188102
# mean_bathrooms       0.392160      0.020625        0.128236
#
#                     mean_accommodates  mean_monthly_price  mean_bathrooms
# mean_beds                    0.838515            0.502365        0.392160
# mean_reviews                -0.050292            0.087380        0.020625
# mean_amenities               0.155906            0.188102        0.128236
# mean_accommodates            1.000000            0.529836        0.379004
# mean_monthly_price           0.529836            1.000000        0.380040
# mean_bathrooms               0.379004            0.380040        1.000000

# %% [markdown]
# ## Forward Stepwise Model

# %%
def forward_selection(data, y, predictors, current_predictors):
    #print(len(current_predictors), current_predictors)
    aic_k_best = 1e+8
    for predictor_to_add in (predictors - current_predictors):
        new_predictors = current_predictors.copy()
        new_predictors.add(predictor_to_add)
        formula = y + ' ~ ' + ' + '.join(new_predictors)
        model = smf.ols(formula, data=data).fit()
        #print('\t', model.aic, new_predictors)
        if model.aic <= aic_k_best:
            aic_k_best = model.aic
            model_k_best = model
            predictors_k_best = new_predictors
    #print('best: ', model_k_best.aic, predictors_k_best)
    return model_k_best, predictors_k_best

# Step 1: start with Model 0
predictors = set(list(data2.columns))
predictors.remove('id')
predictors.remove('price')
current_predictors = set()
model_0 = smf.ols('price ~ 1', data=data2).fit()
aic_fwd = model_0.aic
model_fwd = model_0
predictors_fwd = current_predictors
# Step 2: iteratively add predictor one by one

while len(current_predictors) < len(predictors):
    model, current_predictors = forward_selection(data2, 'price', predictors, current_predictors)
    print(len(current_predictors), model.aic, current_predictors)
    if model.aic <= aic_fwd:
        aic_fwd = model.aic
        model_fwd = model
        predictors_fwd = current_predictors
print('Best Model: ', model_fwd.aic, predictors_fwd)
# Out:
# 1 28766.29011796062 {'mean_monthly_price'}
# 2 28465.324148785134 {'mean_accommodates', 'mean_monthly_price'}
# 3 28364.39978195633 {'mean_accommodates', 'mean_monthly_price', 'mean_bathrooms'}
# 4 28275.361082984025 {'mean_accommodates', 'mean_monthly_price', 'mean_bathrooms', 'neighbourhood'}
# 5 28222.30488955941 {'neighbourhood', 'mean_accommodates', 'mean_monthly_price', 'room_type', 'mean_bathrooms'}
# 6 28197.586033379936 {'mean_accommodates', 'mean_monthly_price', 'neighbourhood', 'room_type', 'property_type', 'mean_bathrooms'}
# 7 28174.174415432535 {'mean_accommodates', 'mean_reviews', 'mean_monthly_price', 'neighbourhood', 'room_type', 'property_type', 'mean_bathrooms'}
# 8 28159.677177615267 {'mean_accommodates', 'mean_reviews', 'mean_monthly_price', 'mean_amenities', 'neighbourhood', 'room_type', 'property_type', 'mean_bathrooms'}
# 9 28153.027289354613 {'mean_reviews', 'mean_beds', 'mean_amenities', 'neighbourhood', 'mean_accommodates', 'mean_monthly_price', 'room_type', 'property_type', 'mean_bathrooms'}
# Best Model:  28153.027289354613 {'mean_reviews', 'mean_beds', 'mean_amenities', 'neighbourhood', 'mean_accommodates', 'mean_monthly_price', 'room_type', 'property_type', 'mean_bathrooms'}

# %% [markdown]
# ## Checking for multicollinearity

# %%
data2[list(predictors_fwd)].corr()
# Out:
#                     mean_reviews  mean_beds  mean_amenities  \
# mean_reviews            1.000000  -0.034184        0.130053
# mean_beds              -0.034184   1.000000        0.176819
# mean_amenities          0.130053   0.176819        1.000000
# mean_accommodates      -0.050292   0.838515        0.155906
# mean_monthly_price      0.087380   0.502365        0.188102
# mean_bathrooms          0.020625   0.392160        0.128236
#
#                     mean_accommodates  mean_monthly_price  mean_bathrooms
# mean_reviews                -0.050292            0.087380        0.020625
# mean_beds                    0.838515            0.502365        0.392160
# mean_amenities               0.155906            0.188102        0.128236
# mean_accommodates            1.000000            0.529836        0.379004
# mean_monthly_price           0.529836            1.000000        0.380040
# mean_bathrooms               0.379004            0.380040        1.000000

# %%
model_fwd.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     122.9
# Date:                Wed, 21 Nov 2018   Prob (F-statistic):               0.00
# Time:                        20:17:49   Log-Likelihood:                -14032.
# No. Observations:                2695   AIC:                         2.815e+04
# Df Residuals:                    2650   BIC:                         2.842e+04
# Df Model:                          44
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept                                                -110.3247     23.760     -4.643      0.000    -156.916     -63.734
# neighbourhood[T.Bijlmer-Oost]                              -4.8886     19.283     -0.254      0.800     -42.699      32.922
# neighbourhood[T.Bos en Lommer]                             16.5485     16.270      1.017      0.309     -15.355      48.452
# neighbourhood[T.Buitenveldert - Zuidas]                    14.0049     17.588      0.796      0.426     -20.482      48.492
# neighbourhood[T.Centrum-Oost]                              38.9692     16.058      2.427      0.015       7.481      70.457
# neighbourhood[T.Centrum-West]                              37.5879     15.991      2.351      0.019       6.232      68.944
# neighbourhood[T.De Aker - Nieuw Sloten]                    -7.0836     20.266     -0.350      0.727     -46.822      32.655
# neighbourhood[T.De Baarsjes - Oud-West]                    20.9572     15.947      1.314      0.189     -10.313      52.227
# neighbourhood[T.De Pijp - Rivierenbuurt]                   23.1829     16.001      1.449      0.147      -8.192      54.558
# neighbourhood[T.Gaasperdam - Driemond]                     -8.7157     21.800     -0.400      0.689     -51.462      34.031
# neighbourhood[T.Geuzenveld - Slotermeer]                    8.2500     17.948      0.460      0.646     -26.943      43.443
# neighbourhood[T.IJburg - Zeeburgereiland]                   8.6944     17.403      0.500      0.617     -25.430      42.819
# neighbourhood[T.Noord-Oost]                                -3.0141     18.025     -0.167      0.867     -38.358      32.330
# neighbourhood[T.Noord-West]                                -1.0396     18.326     -0.057      0.955     -36.975      34.896
# neighbourhood[T.Oostelijk Havengebied - Indische Buurt]    23.5512     16.268      1.448      0.148      -8.348      55.451
# neighbourhood[T.Osdorp]                                    -5.2681     20.715     -0.254      0.799     -45.887      35.351
# neighbourhood[T.Oud-Noord]                                  4.6909     16.636      0.282      0.778     -27.930      37.312
# neighbourhood[T.Oud-Oost]                                  20.9020     16.229      1.288      0.198     -10.921      52.725
# neighbourhood[T.Slotervaart]                               26.4917     17.246      1.536      0.125      -7.326      60.309
# neighbourhood[T.Watergraafsmeer]                            6.9846     16.708      0.418      0.676     -25.777      39.746
# neighbourhood[T.Westerpark]                                21.0923     16.159      1.305      0.192     -10.593      52.777
# neighbourhood[T.Zuid]                                      26.2909     16.144      1.629      0.104      -5.366      57.947
# room_type[T.Private room]                                 -16.7785      2.431     -6.903      0.000     -21.544     -12.013
# room_type[T.Shared room]                                  -53.4875     17.268     -3.097      0.002     -87.348     -19.627
# property_type[T.Bed & Breakfast]                            0.3240      4.739      0.068      0.946      -8.969       9.617
# property_type[T.Boat]                                      17.1519      4.743      3.617      0.000       7.852      26.451
# property_type[T.Bungalow]                                   3.8478     45.567      0.084      0.933     -85.503      93.199
# property_type[T.Cabin]                                    -15.1317     18.718     -0.808      0.419     -51.835      21.572
# property_type[T.Chalet]                                     3.1750     32.323      0.098      0.922     -60.206      66.556
# property_type[T.Condominium]                               -4.5057      8.504     -0.530      0.596     -21.181      12.170
# property_type[T.Dorm]                                      46.8727     48.329      0.970      0.332     -47.894     141.640
# property_type[T.Earth House]                               29.9457     44.827      0.668      0.504     -57.953     117.844
# property_type[T.Guest suite]                              -28.6958     25.981     -1.104      0.269     -79.641      22.249
# property_type[T.House]                                     17.2266      3.263      5.279      0.000      10.828      23.625
# property_type[T.Loft]                                       6.7076      7.992      0.839      0.401      -8.963      22.378
# property_type[T.Other]                                    -28.8671     13.181     -2.190      0.029     -54.712      -3.022
# property_type[T.Serviced apartment]                       -20.4536     44.700     -0.458      0.647    -108.104      67.197
# property_type[T.Townhouse]                                  3.7351      9.461      0.395      0.693     -14.817      22.287
# property_type[T.Villa]                                     21.0004     31.805      0.660      0.509     -41.365      83.366
# mean_reviews                                                8.5571      1.950      4.389      0.000       4.734      12.380
# mean_beds                                                   3.4505      1.182      2.919      0.004       1.132       5.769
# mean_amenities                                              0.6331      0.163      3.873      0.000       0.313       0.954
# mean_accommodates                                          10.5388      1.237      8.517      0.000       8.112      12.965
# mean_monthly_price                                          0.0239      0.001     33.811      0.000       0.022       0.025
# mean_bathrooms                                             31.6652      3.132     10.111      0.000      25.524      37.806
# ==============================================================================
# Omnibus:                     1185.700   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            79590.491
# Skew:                           1.236   Prob(JB):                         0.00
# Kurtosis:                      29.508   Cond. No.                     2.66e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.66e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Best Subset Model

# %%
data2_predictors = list(data2.columns)
data2_predictors.remove('price')
data2_predictors.remove('id')
p = len(data2_predictors)
import itertools
def best_subset(data, y, predictors, k):
    if k == 0:
        predictors_k_best = set()
        model_k_best = smf.ols(y + ' ~ 1', data=data).fit()
    else:
        aic_k_best = 1e+8
        for predictor_set in itertools.combinations(predictors, k):
            formula_k = y + ' ~ ' + ' + '.join(predictor_set)
            model_k = smf.ols(formula_k, data=data).fit()
            #print('\t', model_k.aic, predictor_set)
            if model_k.aic <= aic_k_best:
                aic_k_best = model_k.aic
                model_k_best = model_k
                predictors_k_best = predictor_set
    return model_k_best, predictors_k_best

# %%
aic_best = 1e+8
for k in range(0, p+1, 1):
    model_k, predictors_k = best_subset(data2, 'price', data2_predictors, k)
    print(k, model_k.aic, predictors_k)
    if model_k.aic <= aic_best:
        aic_best = model_k.aic
        k_best = k
        model_best = model_k
        predictors_best = predictors_k
print('Best Model: ', k_best, model_best.aic, predictors_best)
# Out:
# 0 31061.761481365756 set()
# 1 28766.29011796062 ('mean_monthly_price',)
# 2 28465.324148785134 ('mean_monthly_price', 'mean_accommodates')
# 3 28364.39978195633 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms')
# 4 28275.361082984025 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms', 'neighbourhood')
# 5 28222.30488955941 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms', 'neighbourhood', 'room_type')
# 6 28197.586033379936 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms', 'neighbourhood', 'property_type', 'room_type')
# 7 28174.174415432535 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms', 'mean_reviews', 'neighbourhood', 'property_type', 'room_type')
# 8 28159.677177615267 ('mean_monthly_price', 'mean_amenities', 'mean_accommodates', 'mean_bathrooms', 'mean_reviews', 'neighbourhood', 'property_type', 'room_type')
# 9 28153.027289354613 ('mean_monthly_price', 'mean_amenities', 'mean_accommodates', 'mean_bathrooms', 'mean_beds', 'mean_reviews', 'neighbourhood', 'property_type', 'room_type')
# Best Model:  9 28153.027289354613 ('mean_monthly_price', 'mean_amenities', 'mean_accommodates', 'mean_bathrooms', 'mean_beds', 'mean_reviews', 'neighbourhood', 'property_type', 'room_type')

# %%
model_best.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     122.9
# Date:                Wed, 21 Nov 2018   Prob (F-statistic):               0.00
# Time:                        20:18:10   Log-Likelihood:                -14032.
# No. Observations:                2695   AIC:                         2.815e+04
# Df Residuals:                    2650   BIC:                         2.842e+04
# Df Model:                          44
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept                                                -110.3247     23.760     -4.643      0.000    -156.916     -63.734
# neighbourhood[T.Bijlmer-Oost]                              -4.8886     19.283     -0.254      0.800     -42.699      32.922
# neighbourhood[T.Bos en Lommer]                             16.5485     16.270      1.017      0.309     -15.355      48.452
# neighbourhood[T.Buitenveldert - Zuidas]                    14.0049     17.588      0.796      0.426     -20.482      48.492
# neighbourhood[T.Centrum-Oost]                              38.9692     16.058      2.427      0.015       7.481      70.457
# neighbourhood[T.Centrum-West]                              37.5879     15.991      2.351      0.019       6.232      68.944
# neighbourhood[T.De Aker - Nieuw Sloten]                    -7.0836     20.266     -0.350      0.727     -46.822      32.655
# neighbourhood[T.De Baarsjes - Oud-West]                    20.9572     15.947      1.314      0.189     -10.313      52.227
# neighbourhood[T.De Pijp - Rivierenbuurt]                   23.1829     16.001      1.449      0.147      -8.192      54.558
# neighbourhood[T.Gaasperdam - Driemond]                     -8.7157     21.800     -0.400      0.689     -51.462      34.031
# neighbourhood[T.Geuzenveld - Slotermeer]                    8.2500     17.948      0.460      0.646     -26.943      43.443
# neighbourhood[T.IJburg - Zeeburgereiland]                   8.6944     17.403      0.500      0.617     -25.430      42.819
# neighbourhood[T.Noord-Oost]                                -3.0141     18.025     -0.167      0.867     -38.358      32.330
# neighbourhood[T.Noord-West]                                -1.0396     18.326     -0.057      0.955     -36.975      34.896
# neighbourhood[T.Oostelijk Havengebied - Indische Buurt]    23.5512     16.268      1.448      0.148      -8.348      55.451
# neighbourhood[T.Osdorp]                                    -5.2681     20.715     -0.254      0.799     -45.887      35.351
# neighbourhood[T.Oud-Noord]                                  4.6909     16.636      0.282      0.778     -27.930      37.312
# neighbourhood[T.Oud-Oost]                                  20.9020     16.229      1.288      0.198     -10.921      52.725
# neighbourhood[T.Slotervaart]                               26.4917     17.246      1.536      0.125      -7.326      60.309
# neighbourhood[T.Watergraafsmeer]                            6.9846     16.708      0.418      0.676     -25.777      39.746
# neighbourhood[T.Westerpark]                                21.0923     16.159      1.305      0.192     -10.593      52.777
# neighbourhood[T.Zuid]                                      26.2909     16.144      1.629      0.104      -5.366      57.947
# property_type[T.Bed & Breakfast]                            0.3240      4.739      0.068      0.946      -8.969       9.617
# property_type[T.Boat]                                      17.1519      4.743      3.617      0.000       7.852      26.451
# property_type[T.Bungalow]                                   3.8478     45.567      0.084      0.933     -85.503      93.199
# property_type[T.Cabin]                                    -15.1317     18.718     -0.808      0.419     -51.835      21.572
# property_type[T.Chalet]                                     3.1750     32.323      0.098      0.922     -60.206      66.556
# property_type[T.Condominium]                               -4.5057      8.504     -0.530      0.596     -21.181      12.170
# property_type[T.Dorm]                                      46.8727     48.329      0.970      0.332     -47.894     141.640
# property_type[T.Earth House]                               29.9457     44.827      0.668      0.504     -57.953     117.844
# property_type[T.Guest suite]                              -28.6958     25.981     -1.104      0.269     -79.641      22.249
# property_type[T.House]                                     17.2266      3.263      5.279      0.000      10.828      23.625
# property_type[T.Loft]                                       6.7076      7.992      0.839      0.401      -8.963      22.378
# property_type[T.Other]                                    -28.8671     13.181     -2.190      0.029     -54.712      -3.022
# property_type[T.Serviced apartment]                       -20.4536     44.700     -0.458      0.647    -108.104      67.197
# property_type[T.Townhouse]                                  3.7351      9.461      0.395      0.693     -14.817      22.287
# property_type[T.Villa]                                     21.0004     31.805      0.660      0.509     -41.365      83.366
# room_type[T.Private room]                                 -16.7785      2.431     -6.903      0.000     -21.544     -12.013
# room_type[T.Shared room]                                  -53.4875     17.268     -3.097      0.002     -87.348     -19.627
# mean_monthly_price                                          0.0239      0.001     33.811      0.000       0.022       0.025
# mean_amenities                                              0.6331      0.163      3.873      0.000       0.313       0.954
# mean_accommodates                                          10.5388      1.237      8.517      0.000       8.112      12.965
# mean_bathrooms                                             31.6652      3.132     10.111      0.000      25.524      37.806
# mean_beds                                                   3.4505      1.182      2.919      0.004       1.132       5.769
# mean_reviews                                                8.5571      1.950      4.389      0.000       4.734      12.380
# ==============================================================================
# Omnibus:                     1185.700   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            79590.491
# Skew:                           1.236   Prob(JB):                         0.00
# Kurtosis:                      29.508   Cond. No.                     2.66e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.66e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data2[list(predictors_best)].corr()
# Out:
#                     mean_monthly_price  mean_amenities  mean_accommodates  \
# mean_monthly_price            1.000000        0.188102           0.529836
# mean_amenities                0.188102        1.000000           0.155906
# mean_accommodates             0.529836        0.155906           1.000000
# mean_bathrooms                0.380040        0.128236           0.379004
# mean_beds                     0.502365        0.176819           0.838515
# mean_reviews                  0.087380        0.130053          -0.050292
#
#                     mean_bathrooms  mean_beds  mean_reviews
# mean_monthly_price        0.380040   0.502365      0.087380
# mean_amenities            0.128236   0.176819      0.130053
# mean_accommodates         0.379004   0.838515     -0.050292
# mean_bathrooms            1.000000   0.392160      0.020625
# mean_beds                 0.392160   1.000000     -0.034184
# mean_reviews              0.020625  -0.034184      1.000000

# %% [markdown]
# ## Removing variable with multicollinearity

# %%
data2.drop('mean_beds',inplace=True,axis=1)
data2.head()
# Out:
#       id       price  mean_monthly_price  mean_amenities  mean_accommodates  \
# 0   2818   71.083333              1500.0       25.000000                2.0
# 1   3209  132.166667              2000.0       20.583333                4.0
# 2   8061  135.000000              2400.0       17.000000                2.0
# 3  27886  145.000000              2500.0       17.666667                2.0
# 4  29051   55.000000              1435.0       11.000000                1.0
#
#    mean_bathrooms  mean_reviews                           neighbourhood  \
# 0             1.5      9.675000  Oostelijk Havengebied - Indische Buurt
# 1             1.0      9.364583                              Westerpark
# 2             1.0     10.000000                  De Baarsjes - Oud-West
# 3             1.0      9.975000                            Centrum-West
# 4             1.0      9.610000                            Centrum-West
#
#   property_type        room_type
# 0     Apartment     Private room
# 1   Condominium  Entire home/apt
# 2     Apartment  Entire home/apt
# 3     Apartment     Private room
# 4         House     Private room

# %% [markdown]
# ## Running Best Subset Model again

# %%
data2_predictors = list(data2.columns)
data2_predictors.remove('price')
data2_predictors.remove('id')
p = len(data2_predictors)
import itertools
def best_subset(data, y, predictors, k):
    if k == 0:
        predictors_k_best = set()
        model_k_best = smf.ols(y + ' ~ 1', data=data).fit()
    else:
        aic_k_best = 1e+8
        for predictor_set in itertools.combinations(predictors, k):
            formula_k = y + ' ~ ' + ' + '.join(predictor_set)
            model_k = smf.ols(formula_k, data=data).fit()
            #print('\t', model_k.aic, predictor_set)
            if model_k.aic <= aic_k_best:
                aic_k_best = model_k.aic
                model_k_best = model_k
                predictors_k_best = predictor_set
    return model_k_best, predictors_k_best

aic_best = 1e+8
for k in range(0, p+1, 1):
    model_k, predictors_k = best_subset(data2, 'price', data2_predictors, k)
    print(k, model_k.aic, predictors_k)
    if model_k.aic <= aic_best:
        aic_best = model_k.aic
        k_best = k
        model_best = model_k
        predictors_best = predictors_k
print('Best Model: ', k_best, model_best.aic, predictors_best)
# Out:
# 0 31061.761481365756 set()
# 1 28766.29011796062 ('mean_monthly_price',)
# 2 28465.324148785134 ('mean_monthly_price', 'mean_accommodates')
# 3 28364.39978195633 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms')
# 4 28275.361082984025 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms', 'neighbourhood')
# 5 28222.30488955941 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms', 'neighbourhood', 'room_type')
# 6 28197.586033379936 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms', 'neighbourhood', 'property_type', 'room_type')
# 7 28174.174415432535 ('mean_monthly_price', 'mean_accommodates', 'mean_bathrooms', 'mean_reviews', 'neighbourhood', 'property_type', 'room_type')
# 8 28159.677177615267 ('mean_monthly_price', 'mean_amenities', 'mean_accommodates', 'mean_bathrooms', 'mean_reviews', 'neighbourhood', 'property_type', 'room_type')
# Best Model:  8 28159.677177615267 ('mean_monthly_price', 'mean_amenities', 'mean_accommodates', 'mean_bathrooms', 'mean_reviews', 'neighbourhood', 'property_type', 'room_type')

# %%
model_best.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.665
# Method:                 Least Squares   F-statistic:                     125.2
# Date:                Wed, 21 Nov 2018   Prob (F-statistic):               0.00
# Time:                        20:18:21   Log-Likelihood:                -14036.
# No. Observations:                2695   AIC:                         2.816e+04
# Df Residuals:                    2651   BIC:                         2.842e+04
# Df Model:                          43
# Covariance Type:            nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept                                                -114.9768     23.741     -4.843      0.000    -161.529     -68.425
# neighbourhood[T.Bijlmer-Oost]                              -5.0209     19.310     -0.260      0.795     -42.885      32.843
# neighbourhood[T.Bos en Lommer]                             16.8509     16.293      1.034      0.301     -15.097      48.799
# neighbourhood[T.Buitenveldert - Zuidas]                    14.5378     17.612      0.825      0.409     -19.996      49.072
# neighbourhood[T.Centrum-Oost]                              39.1107     16.081      2.432      0.015       7.578      70.643
# neighbourhood[T.Centrum-West]                              37.4084     16.014      2.336      0.020       6.008      68.809
# neighbourhood[T.De Aker - Nieuw Sloten]                    -7.0796     20.294     -0.349      0.727     -46.874      32.715
# neighbourhood[T.De Baarsjes - Oud-West]                    21.0549     15.970      1.318      0.187     -10.259      52.369
# neighbourhood[T.De Pijp - Rivierenbuurt]                   23.4064     16.023      1.461      0.144      -8.013      54.826
# neighbourhood[T.Gaasperdam - Driemond]                     -7.9840     21.829     -0.366      0.715     -50.788      34.820
# neighbourhood[T.Geuzenveld - Slotermeer]                    9.3272     17.969      0.519      0.604     -25.908      44.562
# neighbourhood[T.IJburg - Zeeburgereiland]                  10.4314     17.417      0.599      0.549     -23.721      44.584
# neighbourhood[T.Noord-Oost]                                -0.9160     18.036     -0.051      0.959     -36.282      34.450
# neighbourhood[T.Noord-West]                                 0.8218     18.341      0.045      0.964     -35.143      36.786
# neighbourhood[T.Oostelijk Havengebied - Indische Buurt]    23.7348     16.291      1.457      0.145      -8.210      55.679
# neighbourhood[T.Osdorp]                                    -5.0734     20.744     -0.245      0.807     -45.750      35.603
# neighbourhood[T.Oud-Noord]                                  5.7122     16.656      0.343      0.732     -26.947      38.372
# neighbourhood[T.Oud-Oost]                                  20.8741     16.252      1.284      0.199     -10.994      52.742
# neighbourhood[T.Slotervaart]                               26.0819     17.270      1.510      0.131      -7.783      59.946
# neighbourhood[T.Watergraafsmeer]                            8.0052     16.728      0.479      0.632     -24.796      40.806
# neighbourhood[T.Westerpark]                                21.3857     16.181      1.322      0.186     -10.344      53.115
# neighbourhood[T.Zuid]                                      26.5839     16.167      1.644      0.100      -5.117      58.285
# property_type[T.Bed & Breakfast]                            0.5809      4.745      0.122      0.903      -8.723       9.885
# property_type[T.Boat]                                      17.6974      4.746      3.729      0.000       8.392      27.003
# property_type[T.Bungalow]                                   2.2873     45.629      0.050      0.960     -87.184      91.758
# property_type[T.Cabin]                                    -16.9399     18.734     -0.904      0.366     -53.675      19.795
# property_type[T.Chalet]                                     3.3452     32.369      0.103      0.918     -60.125      66.816
# property_type[T.Condominium]                               -4.9555      8.515     -0.582      0.561     -21.652      11.741
# property_type[T.Dorm]                                      50.9110     48.378      1.052      0.293     -43.951     145.773
# property_type[T.Earth House]                               29.9740     44.890      0.668      0.504     -58.049     117.997
# property_type[T.Guest suite]                              -28.4868     26.018     -1.095      0.274     -79.504      22.530
# property_type[T.House]                                     17.8936      3.260      5.489      0.000      11.502      24.286
# property_type[T.Loft]                                       7.4667      7.999      0.933      0.351      -8.218      23.151
# property_type[T.Other]                                    -28.8666     13.199     -2.187      0.029     -54.749      -2.985
# property_type[T.Serviced apartment]                       -22.7472     44.756     -0.508      0.611    -110.508      65.014
# property_type[T.Townhouse]                                  4.9071      9.466      0.518      0.604     -13.654      23.469
# property_type[T.Villa]                                     20.3407     31.850      0.639      0.523     -42.112      82.793
# room_type[T.Private room]                                 -16.3479      2.429     -6.729      0.000     -21.112     -11.584
# room_type[T.Shared room]                                  -52.0410     17.285     -3.011      0.003     -85.935     -18.147
# mean_monthly_price                                          0.0241      0.001     34.315      0.000       0.023       0.025
# mean_amenities                                              0.6594      0.163      4.035      0.000       0.339       0.980
# mean_accommodates                                          13.2287      0.827     15.998      0.000      11.607      14.850
# mean_bathrooms                                             32.7125      3.115     10.500      0.000      26.603      38.821
# mean_reviews                                                8.6376      1.952      4.425      0.000       4.810      12.466
# ==============================================================================
# Omnibus:                     1159.022   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            81060.126
# Skew:                           1.176   Prob(JB):                         0.00
# Kurtosis:                      29.764   Cond. No.                     2.66e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.66e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data2[list(predictors_best)].corr()
# Out:
#                     mean_monthly_price  mean_amenities  mean_accommodates  \
# mean_monthly_price            1.000000        0.188102           0.529836
# mean_amenities                0.188102        1.000000           0.155906
# mean_accommodates             0.529836        0.155906           1.000000
# mean_bathrooms                0.380040        0.128236           0.379004
# mean_reviews                  0.087380        0.130053          -0.050292
#
#                     mean_bathrooms  mean_reviews
# mean_monthly_price        0.380040      0.087380
# mean_amenities            0.128236      0.130053
# mean_accommodates         0.379004     -0.050292
# mean_bathrooms            1.000000      0.020625
# mean_reviews              0.020625      1.000000

# %% [markdown]
# # Comparing price and numerical predictors

# %% [markdown]
# ### Price per Amenity

# %%
data2['mean_bathrooms'].replace(0,np.nan,inplace=True)
data2 = data2[data2['mean_bathrooms'].notna()].reset_index(drop=True)
data2
# Out:
#             id       price  mean_monthly_price  mean_amenities  \
# 0         2818   71.083333              1500.0       25.000000
# 1         3209  132.166667              2000.0       20.583333
# 2         8061  135.000000              2400.0       17.000000
# 3        27886  145.000000              2500.0       17.666667
# 4        29051   55.000000              1435.0       11.000000
# 5        31080  220.750000              4000.0       20.166667
# 6        41075   70.000000              1000.0       11.000000
# 7        42970  149.000000              3000.0       21.750000
# 8        43109  210.000000              4500.0       14.000000
# 9        43980  100.000000              1250.0       14.111111
# 10       45618  105.000000              1800.0       10.000000
# 11       48149  101.666667              1845.0       13.666667
# 12       49790  219.916667              3750.0       16.000000
# 13       50523  110.000000              2300.0       13.000000
# 14       50570   90.000000              1500.0       16.833333
# 15       51667  110.000000              2102.0       24.000000
# 16       52490   76.166667              1400.0       12.000000
# 17       53233  178.000000              3192.0       15.000000
# 18       53671   75.000000              1300.0       12.916667
# 19       55256   87.500000              1700.0       10.000000
# 20       55703  250.000000              3000.0       16.000000
# 21       55709  139.000000              2195.0       18.000000
# 22       57811  125.000000              3350.0       18.000000
# 23       57978  125.000000              2100.0       13.000000
# 24       58600  147.500000              4000.0       22.666667
# 25       62015  109.000000              3000.0       17.000000
# 26       63872   99.000000              3600.0       19.500000
# 27       69042  109.416667              2200.0       22.750000
# 28       74385  100.000000              1200.0       23.000000
# 29       75382  100.000000              2100.0       22.666667
# ...        ...         ...                 ...             ...
# 2658  11608012   39.800000               875.0       10.200000
# 2659  11764965  100.000000               750.0       13.000000
# 2660  12023314   99.000000              2060.0       21.000000
# 2661  12039992  195.000000              3000.0       22.714286
# 2662  12081801   98.000000              1650.0        9.000000
# 2663  12102884   90.000000              2000.0       11.250000
# 2664  12140473  131.500000              3799.0       15.000000
# 2665  12426117  350.000000              9011.0       12.000000
# 2666  12460529  120.000000              1500.0       14.000000
# 2667  12577304  138.444444              2877.0       25.888889
# 2668  12623653   80.833333              2000.0        6.000000
# 2669  12658044  142.500000              1470.0       21.000000
# 2670  12692394  120.000000              3206.0       17.000000
# 2671  12694820   90.000000              1750.0       20.000000
# 2672  12862861  124.416667              1950.0        9.416667
# 2673  13069832   93.000000              1200.0       18.000000
# 2674  13123216  120.000000              3000.0       16.500000
# 2675  13163687  136.777778              2900.0       14.888889
# 2676  13208007   70.833333              1300.0       12.000000
# 2677  13337449  145.833333              1800.0       13.000000
# 2678  13476744  285.000000              4001.0       12.000000
# 2679  13492709   89.000000              2500.0       14.000000
# 2680  13703682   93.333333              1200.0       24.583333
# 2681  13807292  130.000000              3000.0       24.083333
# 2682  13933894   95.000000              3123.0       22.000000
# 2683  13940956   91.500000              1800.0       14.833333
# 2684  13953811  118.000000              2590.0       10.000000
# 2685  13965089  104.166667              2903.0       15.000000
# 2686  13970582   80.000000              1750.0       11.000000
# 2687  14046160   95.000000              1850.0       17.000000
#
#       mean_accommodates  mean_bathrooms  mean_reviews  \
# 0              2.000000             1.5      9.675000
# 1              4.000000             1.0      9.364583
# 2              2.000000             1.0     10.000000
# 3              2.000000             1.0      9.975000
# 4              1.000000             1.0      9.610000
# 5              4.000000             1.0      9.370833
# 6              4.000000             1.0      9.350000
# 7              2.000000             1.0      9.700000
# 8              4.333333             1.0      9.675000
# 9              2.000000             1.0      8.500000
# 10             4.000000             1.0      9.000000
# 11             2.000000             1.0      9.625000
# 12             4.000000             1.0      9.725000
# 13             2.000000             1.0      9.808333
# 14             4.000000             1.0      9.025000
# 15             2.000000             1.0      9.850000
# 16             2.000000             1.5      9.293750
# 17             4.000000             1.0      9.625000
# 18             2.000000             1.0      9.275000
# 19             2.000000             1.0      9.543750
# 20             4.000000             1.0      9.500000
# 21             3.000000             1.0     10.000000
# 22             2.000000             1.0      9.975000
# 23             3.000000             1.0      9.562500
# 24             6.000000             1.0      9.250000
# 25             2.000000             1.0      9.465909
# 26             3.000000             1.0      9.375000
# 27             2.250000             1.0      9.591667
# 28             4.000000             1.0      9.236111
# 29             3.000000             1.0      9.347917
# ...                 ...             ...           ...
# 2658           3.000000             1.5      8.890000
# 2659           2.000000             1.0      9.750000
# 2660           4.000000             1.0      9.700000
# 2661           4.000000             1.0      9.914286
# 2662           2.000000             1.0      8.925000
# 2663           2.000000             1.0     10.000000
# 2664           2.000000             1.0     10.000000
# 2665           7.000000             1.0      9.625000
# 2666           2.000000             1.0      9.325000
# 2667           4.000000             1.5      9.652778
# 2668           3.000000             1.0      8.945833
# 2669           4.000000             1.0      9.796875
# 2670           2.000000             1.0      9.525000
# 2671           4.000000             1.0      9.952083
# 2672           2.000000             1.0      9.050000
# 2673           2.000000             1.0      9.691667
# 2674           4.000000             1.0      9.316667
# 2675           4.000000             1.0      9.575000
# 2676           2.000000             1.0      9.322917
# 2677           4.000000             1.0      8.950000
# 2678           5.000000             1.5      9.750000
# 2679           2.000000             1.0      9.925000
# 2680           4.000000             1.0      9.208333
# 2681           3.000000             1.0      9.700000
# 2682           2.000000             1.0      9.382143
# 2683           4.000000             1.0      9.585417
# 2684           4.000000             1.0      9.820833
# 2685           5.666667             1.0      9.008333
# 2686           2.000000             1.0      7.000000
# 2687           4.000000             1.0      9.500000
#
#                                neighbourhood    property_type        room_type
# 0     Oostelijk Havengebied - Indische Buurt        Apartment     Private room
# 1                                 Westerpark      Condominium  Entire home/apt
# 2                     De Baarsjes - Oud-West        Apartment  Entire home/apt
# 3                               Centrum-West        Apartment     Private room
# 4                               Centrum-West            House     Private room
# 5                                       Zuid        Apartment  Entire home/apt
# 6                              Bos en Lommer        Apartment  Entire home/apt
# 7                               Centrum-West  Bed & Breakfast     Private room
# 8                               Centrum-West        Apartment  Entire home/apt
# 9                                       Zuid        Apartment  Entire home/apt
# 10                                Westerpark        Apartment  Entire home/apt
# 11                   De Pijp - Rivierenbuurt        Apartment     Private room
# 12                    De Baarsjes - Oud-West             Boat  Entire home/apt
# 13                              Centrum-West  Bed & Breakfast     Private room
# 14                             Bos en Lommer        Apartment  Entire home/apt
# 15                    De Baarsjes - Oud-West        Apartment  Entire home/apt
# 16    Oostelijk Havengebied - Indische Buurt  Bed & Breakfast     Private room
# 17                  IJburg - Zeeburgereiland            House  Entire home/apt
# 18                                Westerpark        Apartment     Private room
# 19                              Centrum-Oost        Apartment     Private room
# 20                             Bos en Lommer        Apartment  Entire home/apt
# 21                              Centrum-Oost        Apartment  Entire home/apt
# 22                              Centrum-Oost        Apartment  Entire home/apt
# 23                    De Baarsjes - Oud-West        Apartment  Entire home/apt
# 24                                Westerpark        Apartment  Entire home/apt
# 25                                  Oud-Oost        Apartment  Entire home/apt
# 26                              Centrum-Oost        Apartment  Entire home/apt
# 27                              Centrum-West        Apartment     Private room
# 28                                  Oud-Oost        Apartment  Entire home/apt
# 29                                  Oud-Oost            House     Private room
# ...                                      ...              ...              ...
# 2658                         Bijlmer-Centrum            House     Private room
# 2659                              Westerpark        Apartment  Entire home/apt
# 2660                            Bijlmer-Oost        Apartment  Entire home/apt
# 2661                                    Zuid        Apartment  Entire home/apt
# 2662                  De Baarsjes - Oud-West        Apartment  Entire home/apt
# 2663  Oostelijk Havengebied - Indische Buurt        Apartment  Entire home/apt
# 2664                              Westerpark        Apartment  Entire home/apt
# 2665                            Centrum-West        Apartment  Entire home/apt
# 2666                              Noord-Oost        Apartment  Entire home/apt
# 2667                   Gaasperdam - Driemond        Apartment  Entire home/apt
# 2668                 De Pijp - Rivierenbuurt        Apartment     Private room
# 2669                                    Zuid        Apartment  Entire home/apt
# 2670                            Centrum-West        Apartment  Entire home/apt
# 2671  Oostelijk Havengebied - Indische Buurt        Apartment  Entire home/apt
# 2672  Oostelijk Havengebied - Indische Buurt        Apartment     Private room
# 2673                              Westerpark        Apartment  Entire home/apt
# 2674                         Watergraafsmeer        Apartment  Entire home/apt
# 2675                            Centrum-Oost        Apartment  Entire home/apt
# 2676                 Geuzenveld - Slotermeer        Apartment     Private room
# 2677                              Noord-West            House  Entire home/apt
# 2678                            Centrum-West        Apartment  Entire home/apt
# 2679                                    Zuid      Condominium  Entire home/apt
# 2680                               Oud-Noord            House  Entire home/apt
# 2681                            Centrum-Oost        Apartment  Entire home/apt
# 2682                            Centrum-Oost        Apartment  Entire home/apt
# 2683                  De Aker - Nieuw Sloten            Cabin  Entire home/apt
# 2684                              Westerpark        Apartment  Entire home/apt
# 2685                         Bijlmer-Centrum        Apartment  Entire home/apt
# 2686                            Centrum-West        Apartment  Entire home/apt
# 2687                           Bos en Lommer      Condominium  Entire home/apt
#
# [2688 rows x 10 columns]

# %%
data2['price_per_amenity'] = data2['price'] / data2['mean_amenities']
data2
# Out:
#             id       price  mean_monthly_price  mean_amenities  \
# 0         2818   71.083333              1500.0       25.000000
# 1         3209  132.166667              2000.0       20.583333
# 2         8061  135.000000              2400.0       17.000000
# 3        27886  145.000000              2500.0       17.666667
# 4        29051   55.000000              1435.0       11.000000
# 5        31080  220.750000              4000.0       20.166667
# 6        41075   70.000000              1000.0       11.000000
# 7        42970  149.000000              3000.0       21.750000
# 8        43109  210.000000              4500.0       14.000000
# 9        43980  100.000000              1250.0       14.111111
# 10       45618  105.000000              1800.0       10.000000
# 11       48149  101.666667              1845.0       13.666667
# 12       49790  219.916667              3750.0       16.000000
# 13       50523  110.000000              2300.0       13.000000
# 14       50570   90.000000              1500.0       16.833333
# 15       51667  110.000000              2102.0       24.000000
# 16       52490   76.166667              1400.0       12.000000
# 17       53233  178.000000              3192.0       15.000000
# 18       53671   75.000000              1300.0       12.916667
# 19       55256   87.500000              1700.0       10.000000
# 20       55703  250.000000              3000.0       16.000000
# 21       55709  139.000000              2195.0       18.000000
# 22       57811  125.000000              3350.0       18.000000
# 23       57978  125.000000              2100.0       13.000000
# 24       58600  147.500000              4000.0       22.666667
# 25       62015  109.000000              3000.0       17.000000
# 26       63872   99.000000              3600.0       19.500000
# 27       69042  109.416667              2200.0       22.750000
# 28       74385  100.000000              1200.0       23.000000
# 29       75382  100.000000              2100.0       22.666667
# ...        ...         ...                 ...             ...
# 2658  11608012   39.800000               875.0       10.200000
# 2659  11764965  100.000000               750.0       13.000000
# 2660  12023314   99.000000              2060.0       21.000000
# 2661  12039992  195.000000              3000.0       22.714286
# 2662  12081801   98.000000              1650.0        9.000000
# 2663  12102884   90.000000              2000.0       11.250000
# 2664  12140473  131.500000              3799.0       15.000000
# 2665  12426117  350.000000              9011.0       12.000000
# 2666  12460529  120.000000              1500.0       14.000000
# 2667  12577304  138.444444              2877.0       25.888889
# 2668  12623653   80.833333              2000.0        6.000000
# 2669  12658044  142.500000              1470.0       21.000000
# 2670  12692394  120.000000              3206.0       17.000000
# 2671  12694820   90.000000              1750.0       20.000000
# 2672  12862861  124.416667              1950.0        9.416667
# 2673  13069832   93.000000              1200.0       18.000000
# 2674  13123216  120.000000              3000.0       16.500000
# 2675  13163687  136.777778              2900.0       14.888889
# 2676  13208007   70.833333              1300.0       12.000000
# 2677  13337449  145.833333              1800.0       13.000000
# 2678  13476744  285.000000              4001.0       12.000000
# 2679  13492709   89.000000              2500.0       14.000000
# 2680  13703682   93.333333              1200.0       24.583333
# 2681  13807292  130.000000              3000.0       24.083333
# 2682  13933894   95.000000              3123.0       22.000000
# 2683  13940956   91.500000              1800.0       14.833333
# 2684  13953811  118.000000              2590.0       10.000000
# 2685  13965089  104.166667              2903.0       15.000000
# 2686  13970582   80.000000              1750.0       11.000000
# 2687  14046160   95.000000              1850.0       17.000000
#
#       mean_accommodates  mean_bathrooms  mean_reviews  \
# 0              2.000000             1.5      9.675000
# 1              4.000000             1.0      9.364583
# 2              2.000000             1.0     10.000000
# 3              2.000000             1.0      9.975000
# 4              1.000000             1.0      9.610000
# 5              4.000000             1.0      9.370833
# 6              4.000000             1.0      9.350000
# 7              2.000000             1.0      9.700000
# 8              4.333333             1.0      9.675000
# 9              2.000000             1.0      8.500000
# 10             4.000000             1.0      9.000000
# 11             2.000000             1.0      9.625000
# 12             4.000000             1.0      9.725000
# 13             2.000000             1.0      9.808333
# 14             4.000000             1.0      9.025000
# 15             2.000000             1.0      9.850000
# 16             2.000000             1.5      9.293750
# 17             4.000000             1.0      9.625000
# 18             2.000000             1.0      9.275000
# 19             2.000000             1.0      9.543750
# 20             4.000000             1.0      9.500000
# 21             3.000000             1.0     10.000000
# 22             2.000000             1.0      9.975000
# 23             3.000000             1.0      9.562500
# 24             6.000000             1.0      9.250000
# 25             2.000000             1.0      9.465909
# 26             3.000000             1.0      9.375000
# 27             2.250000             1.0      9.591667
# 28             4.000000             1.0      9.236111
# 29             3.000000             1.0      9.347917
# ...                 ...             ...           ...
# 2658           3.000000             1.5      8.890000
# 2659           2.000000             1.0      9.750000
# 2660           4.000000             1.0      9.700000
# 2661           4.000000             1.0      9.914286
# 2662           2.000000             1.0      8.925000
# 2663           2.000000             1.0     10.000000
# 2664           2.000000             1.0     10.000000
# 2665           7.000000             1.0      9.625000
# 2666           2.000000             1.0      9.325000
# 2667           4.000000             1.5      9.652778
# 2668           3.000000             1.0      8.945833
# 2669           4.000000             1.0      9.796875
# 2670           2.000000             1.0      9.525000
# 2671           4.000000             1.0      9.952083
# 2672           2.000000             1.0      9.050000
# 2673           2.000000             1.0      9.691667
# 2674           4.000000             1.0      9.316667
# 2675           4.000000             1.0      9.575000
# 2676           2.000000             1.0      9.322917
# 2677           4.000000             1.0      8.950000
# 2678           5.000000             1.5      9.750000
# 2679           2.000000             1.0      9.925000
# 2680           4.000000             1.0      9.208333
# 2681           3.000000             1.0      9.700000
# 2682           2.000000             1.0      9.382143
# 2683           4.000000             1.0      9.585417
# 2684           4.000000             1.0      9.820833
# 2685           5.666667             1.0      9.008333
# 2686           2.000000             1.0      7.000000
# 2687           4.000000             1.0      9.500000
#
#                                neighbourhood    property_type  \
# 0     Oostelijk Havengebied - Indische Buurt        Apartment
# 1                                 Westerpark      Condominium
# 2                     De Baarsjes - Oud-West        Apartment
# 3                               Centrum-West        Apartment
# 4                               Centrum-West            House
# 5                                       Zuid        Apartment
# 6                              Bos en Lommer        Apartment
# 7                               Centrum-West  Bed & Breakfast
# 8                               Centrum-West        Apartment
# 9                                       Zuid        Apartment
# 10                                Westerpark        Apartment
# 11                   De Pijp - Rivierenbuurt        Apartment
# 12                    De Baarsjes - Oud-West             Boat
# 13                              Centrum-West  Bed & Breakfast
# 14                             Bos en Lommer        Apartment
# 15                    De Baarsjes - Oud-West        Apartment
# 16    Oostelijk Havengebied - Indische Buurt  Bed & Breakfast
# 17                  IJburg - Zeeburgereiland            House
# 18                                Westerpark        Apartment
# 19                              Centrum-Oost        Apartment
# 20                             Bos en Lommer        Apartment
# 21                              Centrum-Oost        Apartment
# 22                              Centrum-Oost        Apartment
# 23                    De Baarsjes - Oud-West        Apartment
# 24                                Westerpark        Apartment
# 25                                  Oud-Oost        Apartment
# 26                              Centrum-Oost        Apartment
# 27                              Centrum-West        Apartment
# 28                                  Oud-Oost        Apartment
# 29                                  Oud-Oost            House
# ...                                      ...              ...
# 2658                         Bijlmer-Centrum            House
# 2659                              Westerpark        Apartment
# 2660                            Bijlmer-Oost        Apartment
# 2661                                    Zuid        Apartment
# 2662                  De Baarsjes - Oud-West        Apartment
# 2663  Oostelijk Havengebied - Indische Buurt        Apartment
# 2664                              Westerpark        Apartment
# 2665                            Centrum-West        Apartment
# 2666                              Noord-Oost        Apartment
# 2667                   Gaasperdam - Driemond        Apartment
# 2668                 De Pijp - Rivierenbuurt        Apartment
# 2669                                    Zuid        Apartment
# 2670                            Centrum-West        Apartment
# 2671  Oostelijk Havengebied - Indische Buurt        Apartment
# 2672  Oostelijk Havengebied - Indische Buurt        Apartment
# 2673                              Westerpark        Apartment
# 2674                         Watergraafsmeer        Apartment
# 2675                            Centrum-Oost        Apartment
# 2676                 Geuzenveld - Slotermeer        Apartment
# 2677                              Noord-West            House
# 2678                            Centrum-West        Apartment
# 2679                                    Zuid      Condominium
# 2680                               Oud-Noord            House
# 2681                            Centrum-Oost        Apartment
# 2682                            Centrum-Oost        Apartment
# 2683                  De Aker - Nieuw Sloten            Cabin
# 2684                              Westerpark        Apartment
# 2685                         Bijlmer-Centrum        Apartment
# 2686                            Centrum-West        Apartment
# 2687                           Bos en Lommer      Condominium
#
#             room_type  price_per_amenity
# 0        Private room           2.843333
# 1     Entire home/apt           6.421053
# 2     Entire home/apt           7.941176
# 3        Private room           8.207547
# 4        Private room           5.000000
# 5     Entire home/apt          10.946281
# 6     Entire home/apt           6.363636
# 7        Private room           6.850575
# 8     Entire home/apt          15.000000
# 9     Entire home/apt           7.086614
# 10    Entire home/apt          10.500000
# 11       Private room           7.439024
# 12    Entire home/apt          13.744792
# 13       Private room           8.461538
# 14    Entire home/apt           5.346535
# 15    Entire home/apt           4.583333
# 16       Private room           6.347222
# 17    Entire home/apt          11.866667
# 18       Private room           5.806452
# 19       Private room           8.750000
# 20    Entire home/apt          15.625000
# 21    Entire home/apt           7.722222
# 22    Entire home/apt           6.944444
# 23    Entire home/apt           9.615385
# 24    Entire home/apt           6.507353
# 25    Entire home/apt           6.411765
# 26    Entire home/apt           5.076923
# 27       Private room           4.809524
# 28    Entire home/apt           4.347826
# 29       Private room           4.411765
# ...               ...                ...
# 2658     Private room           3.901961
# 2659  Entire home/apt           7.692308
# 2660  Entire home/apt           4.714286
# 2661  Entire home/apt           8.584906
# 2662  Entire home/apt          10.888889
# 2663  Entire home/apt           8.000000
# 2664  Entire home/apt           8.766667
# 2665  Entire home/apt          29.166667
# 2666  Entire home/apt           8.571429
# 2667  Entire home/apt           5.347639
# 2668     Private room          13.472222
# 2669  Entire home/apt           6.785714
# 2670  Entire home/apt           7.058824
# 2671  Entire home/apt           4.500000
# 2672     Private room          13.212389
# 2673  Entire home/apt           5.166667
# 2674  Entire home/apt           7.272727
# 2675  Entire home/apt           9.186567
# 2676     Private room           5.902778
# 2677  Entire home/apt          11.217949
# 2678  Entire home/apt          23.750000
# 2679  Entire home/apt           6.357143
# 2680  Entire home/apt           3.796610
# 2681  Entire home/apt           5.397924
# 2682  Entire home/apt           4.318182
# 2683  Entire home/apt           6.168539
# 2684  Entire home/apt          11.800000
# 2685  Entire home/apt           6.944444
# 2686  Entire home/apt           7.272727
# 2687  Entire home/apt           5.588235
#
# [2688 rows x 11 columns]

# %% [markdown]
# #### Rank top 10 neighbourhood by Price per Amenity

# %%
rank_amenities = (data2.groupby('neighbourhood')['price_per_amenity'].mean()).sort_values()
rank_amenities = rank_amenities.to_frame().reset_index()
rank_amenities['amenity_rank'] = rank_amenities['neighbourhood'].apply(lambda x: '')
for i in range(len(rank_amenities)):
    rank_amenities['amenity_rank'][i] = 22 - i
rank_amenities
# Out:
# C:\Users\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                              neighbourhood  price_per_amenity amenity_rank
# 0                             Bijlmer-Oost           4.372950           22
# 1                                   Osdorp           4.946776           21
# 2                    Gaasperdam - Driemond           4.978460           20
# 3                  Geuzenveld - Slotermeer           5.074234           19
# 4                          Bijlmer-Centrum           5.554615           18
# 5                               Noord-Oost           6.052220           17
# 6                   De Aker - Nieuw Sloten           6.574017           16
# 7                            Bos en Lommer           7.143163           15
# 8                               Noord-West           7.709123           14
# 9                              Slotervaart           7.870999           13
# 10                         Watergraafsmeer           8.196649           12
# 11                                Oud-Oost           8.821420           11
# 12  Oostelijk Havengebied - Indische Buurt           8.877945           10
# 13                  De Baarsjes - Oud-West           9.186239            9
# 14                              Westerpark           9.391164            8
# 15                IJburg - Zeeburgereiland           9.443914            7
# 16                 De Pijp - Rivierenbuurt           9.888997            6
# 17                  Buitenveldert - Zuidas           9.977420            5
# 18                                    Zuid          10.309971            4
# 19                               Oud-Noord          10.357189            3
# 20                            Centrum-Oost          11.112228            2
# 21                            Centrum-West          11.892828            1

# %%
sns.regplot(x='mean_amenities', y='price', data=data2)
plt.ylim(0,2250)
# Out:
# C:\Users\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0, 2250)

# %%
# Plot Neighbourhood against Price per Amenity
plt.figure(figsize=(15,10))
plt.bar(rank_amenities['neighbourhood'],rank_amenities['price_per_amenity'])
plt.title("Price per Amenity in each Neighbourhood")
plt.xlabel('Neighbourhood')
plt.ylabel('Price per Amenity')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Price per Accommodates

# %%
data2['price_per_accommodates'] = data2['price'] / data2['mean_accommodates']
data2[['price_per_accommodates']]
# Out:
#       price_per_accommodates
# 0                  35.541667
# 1                  33.041667
# 2                  67.500000
# 3                  72.500000
# 4                  55.000000
# 5                  55.187500
# 6                  17.500000
# 7                  74.500000
# 8                  48.461538
# 9                  50.000000
# 10                 26.250000
# 11                 50.833333
# 12                 54.979167
# 13                 55.000000
# 14                 22.500000
# 15                 55.000000
# 16                 38.083333
# 17                 44.500000
# 18                 37.500000
# 19                 43.750000
# 20                 62.500000
# 21                 46.333333
# 22                 62.500000
# 23                 41.666667
# 24                 24.583333
# 25                 54.500000
# 26                 33.000000
# 27                 48.629630
# 28                 25.000000
# 29                 33.333333
# ...                      ...
# 2658               13.266667
# 2659               50.000000
# 2660               24.750000
# 2661               48.750000
# 2662               49.000000
# 2663               45.000000
# 2664               65.750000
# 2665               50.000000
# 2666               60.000000
# 2667               34.611111
# 2668               26.944444
# 2669               35.625000
# 2670               60.000000
# 2671               22.500000
# 2672               62.208333
# 2673               46.500000
# 2674               30.000000
# 2675               34.194444
# 2676               35.416667
# 2677               36.458333
# 2678               57.000000
# 2679               44.500000
# 2680               23.333333
# 2681               43.333333
# 2682               47.500000
# 2683               22.875000
# 2684               29.500000
# 2685               18.382353
# 2686               40.000000
# 2687               23.750000
#
# [2688 rows x 1 columns]

# %% [markdown]
# #### Rank top 10 neighbourhood by Price per Accommodates

# %%
rank_accommodates = (data2.groupby('neighbourhood')['price_per_accommodates']).mean().sort_values()
rank_accommodates = rank_accommodates.to_frame().reset_index()
rank_accommodates['accommodates_rank'] = rank_accommodates['neighbourhood'].apply(lambda x: '')
for i in range(len(rank_accommodates)):
    rank_accommodates['accommodates_rank'][i] = 22 - i
rank_accommodates
# Out:
# C:\Users\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                              neighbourhood  price_per_accommodates  \
# 0                             Bijlmer-Oost               23.576442
# 1                    Gaasperdam - Driemond               27.116512
# 2                          Bijlmer-Centrum               29.435294
# 3                                   Osdorp               31.513904
# 4                   De Aker - Nieuw Sloten               32.671785
# 5                  Geuzenveld - Slotermeer               33.142512
# 6                               Noord-Oost               34.277005
# 7                               Noord-West               34.399212
# 8                 IJburg - Zeeburgereiland               37.936535
# 9                                Oud-Noord               38.652427
# 10                         Watergraafsmeer               39.627529
# 11                           Bos en Lommer               42.200413
# 12                  Buitenveldert - Zuidas               42.526990
# 13  Oostelijk Havengebied - Indische Buurt               42.693373
# 14                             Slotervaart               43.076112
# 15                                Oud-Oost               45.089289
# 16                              Westerpark               48.234991
# 17                  De Baarsjes - Oud-West               48.676589
# 18                 De Pijp - Rivierenbuurt               49.257464
# 19                                    Zuid               49.836372
# 20                            Centrum-West               59.844402
# 21                            Centrum-Oost               60.512274
#
#    accommodates_rank
# 0                 22
# 1                 21
# 2                 20
# 3                 19
# 4                 18
# 5                 17
# 6                 16
# 7                 15
# 8                 14
# 9                 13
# 10                12
# 11                11
# 12                10
# 13                 9
# 14                 8
# 15                 7
# 16                 6
# 17                 5
# 18                 4
# 19                 3
# 20                 2
# 21                 1

# %%
sns.regplot(x='mean_accommodates', y='price', data=data2)
# Out:
# C:\Users\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Plot Neighbourhood against Price per Accommodates
plt.figure(figsize=(15,10))
plt.bar(rank_amenities['neighbourhood'],rank_accommodates['price_per_accommodates'])
plt.title("Price per Accommodates in each Neighbourhood")
plt.xlabel('Neighbourhood')
plt.ylabel('Price per Accommodates')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Price per bathroom

# %%
data2['price_per_bathroom'] = data2['price'] / data2['mean_bathrooms']
data2[['price_per_bathroom']]
# Out:
#       price_per_bathroom
# 0              47.388889
# 1             132.166667
# 2             135.000000
# 3             145.000000
# 4              55.000000
# 5             220.750000
# 6              70.000000
# 7             149.000000
# 8             210.000000
# 9             100.000000
# 10            105.000000
# 11            101.666667
# 12            219.916667
# 13            110.000000
# 14             90.000000
# 15            110.000000
# 16             50.777778
# 17            178.000000
# 18             75.000000
# 19             87.500000
# 20            250.000000
# 21            139.000000
# 22            125.000000
# 23            125.000000
# 24            147.500000
# 25            109.000000
# 26             99.000000
# 27            109.416667
# 28            100.000000
# 29            100.000000
# ...                  ...
# 2658           26.533333
# 2659          100.000000
# 2660           99.000000
# 2661          195.000000
# 2662           98.000000
# 2663           90.000000
# 2664          131.500000
# 2665          350.000000
# 2666          120.000000
# 2667           92.296296
# 2668           80.833333
# 2669          142.500000
# 2670          120.000000
# 2671           90.000000
# 2672          124.416667
# 2673           93.000000
# 2674          120.000000
# 2675          136.777778
# 2676           70.833333
# 2677          145.833333
# 2678          190.000000
# 2679           89.000000
# 2680           93.333333
# 2681          130.000000
# 2682           95.000000
# 2683           91.500000
# 2684          118.000000
# 2685          104.166667
# 2686           80.000000
# 2687           95.000000
#
# [2688 rows x 1 columns]

# %% [markdown]
# #### Rank top 10 neighbourhood by Price per Bathroom

# %%
rank_bathrooms = (data2.groupby('neighbourhood')['price_per_bathroom'].mean()).sort_values()
rank_bathrooms = rank_bathrooms.to_frame().reset_index()
rank_bathrooms['bathrooms_rank'] = rank_bathrooms['neighbourhood'].apply(lambda x: '')
for i in range(len(rank_bathrooms)):
    rank_bathrooms['bathrooms_rank'][i] = 22 - i
rank_bathrooms
# Out:
# C:\Users\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                              neighbourhood  price_per_bathroom bathrooms_rank
# 0                             Bijlmer-Oost           68.739583             22
# 1                                   Osdorp           71.257576             21
# 2                          Bijlmer-Centrum           71.879167             20
# 3                    Gaasperdam - Driemond           72.968107             19
# 4                  Geuzenveld - Slotermeer           84.116638             18
# 5                               Noord-Oost           90.999679             17
# 6                            Bos en Lommer           99.506646             16
# 7                   Buitenveldert - Zuidas          101.286348             15
# 8                               Noord-West          104.751052             14
# 9                              Slotervaart          107.360486             13
# 10                         Watergraafsmeer          107.898320             12
# 11  Oostelijk Havengebied - Indische Buurt          108.466701             11
# 12                  De Aker - Nieuw Sloten          108.650350             10
# 13                                Oud-Oost          112.425193              9
# 14                              Westerpark          119.357265              8
# 15                  De Baarsjes - Oud-West          120.499009              7
# 16                               Oud-Noord          121.570007              6
# 17                 De Pijp - Rivierenbuurt          122.564315              5
# 18                IJburg - Zeeburgereiland          124.495494              4
# 19                                    Zuid          135.151262              3
# 20                            Centrum-West          149.251548              2
# 21                            Centrum-Oost          154.125066              1

# %%
sns.regplot(x='mean_bathrooms', y='price', data=data2)
# Out:
# C:\Users\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Plot Neighbourhood against Price per Bathroom
plt.figure(figsize=(15,10))
plt.bar(rank_bathrooms['neighbourhood'],rank_bathrooms['price_per_bathroom'])
plt.title("Price per Bathroom in each Neighbourhood")
plt.xlabel('Neighbourhood')
plt.ylabel('Price per Bathroom')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Price vs Review Score

# %%
print(type(data2['mean_reviews'][1]))
# Out:
# <class 'numpy.float64'>

# %%
# rank_review = (data2.groupby('neighbourhood')['mean_reviews']).count('10.000000')
# # .filter(lambda x: int(x)>9.99999)
# # rank_review['number of max review score'] = rank_review['neighbourhood'][:191].value_counts()
# rank_review
rank_review = data2[['neighbourhood', 'mean_reviews']].sort_values('mean_reviews', ascending=False).reset_index(drop=True)
rank_review['mean_reviews'] = rank_review['mean_reviews'].apply(lambda x: float(x))
rank_review = rank_review[rank_review['mean_reviews']>9.4]
rank_review = rank_review['neighbourhood'].value_counts().to_frame(name='max_review_count').reset_index()
rank_review.columns = ['neighbourhood', 'max_review_count']
rank_review['review_rank'] = rank_review['max_review_count'].apply(lambda x: '')
for i in range(len(rank_review)):
    rank_review['review_rank'][i] = 22 - i
rank_review
# Out:
# C:\Users\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#                              neighbourhood  max_review_count review_rank
# 0                   De Baarsjes - Oud-West               290          22
# 1                             Centrum-West               289          21
# 2                             Centrum-Oost               219          20
# 3                  De Pijp - Rivierenbuurt               216          19
# 4                                     Zuid               118          18
# 5                               Westerpark               102          17
# 6                                 Oud-Oost                64          16
# 7   Oostelijk Havengebied - Indische Buurt                54          15
# 8                            Bos en Lommer                43          14
# 9                          Watergraafsmeer                36          13
# 10                               Oud-Noord                24          12
# 11                IJburg - Zeeburgereiland                20          11
# 12                             Slotervaart                19          10
# 13                  Buitenveldert - Zuidas                16           9
# 14                              Noord-Oost                15           8
# 15                              Noord-West                 9           7
# 16                  De Aker - Nieuw Sloten                 8           6
# 17                                  Osdorp                 4           5
# 18                            Bijlmer-Oost                 3           4
# 19                 Geuzenveld - Slotermeer                 2           3
# 20                   Gaasperdam - Driemond                 1           2
# 21                         Bijlmer-Centrum                 1           1

# %% [markdown]
# ### Ranking of Neighbourhood

# %%
overall_rank = rank_accommodates[['neighbourhood','accommodates_rank']]
overall_rank = pd.merge(overall_rank, rank_amenities[['neighbourhood','amenity_rank']],on='neighbourhood')
overall_rank = pd.merge(overall_rank, rank_bathrooms[['neighbourhood', 'bathrooms_rank']],on = 'neighbourhood')
overall_rank = pd.merge(overall_rank, rank_review[['neighbourhood','review_rank']],on='neighbourhood',how='outer')
overall_rank['review_rank'].fillna(5, inplace=True)
overall_rank['overall_ranking'] = overall_rank.loc[:,'accommodates_rank':'review_rank'].sum(axis=1)
overall_rank = overall_rank.sort_values('overall_ranking',ascending=False).reset_index(drop=True) 
overall_rank
# Out:
#                              neighbourhood accommodates_rank amenity_rank  \
# 0                             Bijlmer-Oost                22           22
# 1                                   Osdorp                19           21
# 2                    Gaasperdam - Driemond                21           20
# 3                          Bijlmer-Centrum                20           18
# 4                               Noord-Oost                16           17
# 5                  Geuzenveld - Slotermeer                17           19
# 6                            Bos en Lommer                11           15
# 7                               Noord-West                15           14
# 8                   De Aker - Nieuw Sloten                18           16
# 9                          Watergraafsmeer                12           12
# 10  Oostelijk Havengebied - Indische Buurt                 9           10
# 11                             Slotervaart                 8           13
# 12                                Oud-Oost                 7           11
# 13                  De Baarsjes - Oud-West                 5            9
# 14                  Buitenveldert - Zuidas                10            5
# 15                              Westerpark                 6            8
# 16                IJburg - Zeeburgereiland                14            7
# 17                               Oud-Noord                13            3
# 18                 De Pijp - Rivierenbuurt                 4            6
# 19                                    Zuid                 3            4
# 20                            Centrum-West                 2            1
# 21                            Centrum-Oost                 1            2
#
#    bathrooms_rank  review_rank  overall_ranking
# 0              22            4             70.0
# 1              21            5             66.0
# 2              19            2             62.0
# 3              20            1             59.0
# 4              17            8             58.0
# 5              18            3             57.0
# 6              16           14             56.0
# 7              14            7             50.0
# 8              10            6             50.0
# 9              12           13             49.0
# 10             11           15             45.0
# 11             13           10             44.0
# 12              9           16             43.0
# 13              7           22             43.0
# 14             15            9             39.0
# 15              8           17             39.0
# 16              4           11             36.0
# 17              6           12             34.0
# 18              5           19             34.0
# 19              3           18             28.0
# 20              2           21             26.0
# 21              1           20             24.0

# %% [markdown]
# ### Top 3 Neighbourhoods

# %%
top_neighbourhood = overall_rank.loc[0,'neighbourhood']
second_neighbourhood = overall_rank.loc[1,'neighbourhood']
third_neighbourhood = overall_rank.loc[2,'neighbourhood']

f, axarr = plt.subplots(1,3, sharey=True)
axarr[0].boxplot(data2.loc[data2['neighbourhood'] == top_neighbourhood, 'price'])
axarr[0].set_xlabel(top_neighbourhood)
axarr[0].set_xticks([])
axarr[1].boxplot(data2.loc[data2['neighbourhood'] == second_neighbourhood, 'price'])
axarr[1].set_xlabel(second_neighbourhood)
axarr[1].set_xticks([])
axarr[1].set_title('Prices of Top 3 Neighbourhoods')
axarr[2].boxplot(data2.loc[data2['neighbourhood'] == third_neighbourhood, 'price'])
axarr[2].set_xlabel(third_neighbourhood)
axarr[2].set_xticks([])
# Out:
# []

# %%
data3 = data2.groupby('neighbourhood')['price'].mean().to_frame(name='mean_price').reset_index()
plt.figure(figsize=(15,10))

plt.bar(data3.iloc[:,0],data3.iloc[:,1])
plt.title("Average Price in each Neighbourhood")
plt.xlabel('Neighbourhood')
plt.ylabel('Average Price')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
